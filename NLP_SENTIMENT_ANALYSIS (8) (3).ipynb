# %% [markdown]
# # Importing All Library Files.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import nltk
from nltk import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re,string,unicodedata
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline
from numpy import array
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import re
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the DataSet

# %%
df = pd.read_csv("financial_sentiment_data1.csv")
df
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5842 rows x 2 columns]

# %% [markdown]
# # Exploratory Data Analysis.

# %%
df.shape
# Out:
# (5842, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   5842 non-null   object
#  1   Sentiment  5842 non-null   object
# dtypes: object(2)
# memory usage: 91.4+ KB

# %%
df.dtypes
# Out:
# Sentence     object
# Sentiment    object
# dtype: object

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# Sentence     0
# Sentiment    0
# dtype: int64

# %%
#Checking for Class Imbalance 
sns.countplot(x=df['Sentiment'])
plt.show()
print(df['Sentiment'].value_counts())
# Out:
# neutral     3130
# positive    1852
# negative     860
# Name: Sentiment, dtype: int64

# %%
#  Now let's check how many unique characters (chars) are there.
unique_chars = pd.Series([char for sentence in df["Sentence"] for char in sentence]).unique()
print("Number of unique chars:",len(unique_chars))
print(unique_chars)
# Out:
# Number of unique chars: 119
# ['T' 'h' 'e' ' ' 'G' 'o' 'S' 'l' 'u' 't' 'i' 'n' 's' 'c' 'g' 'y' 'w' 'v'
#  'r' 'a' 'B' 'f' "'" 'P' 'b' 'p' 'd' 'L' ',' 'C' 'm' '.' '$' 'E' 'I' '1'
#  '5' '0' '2' 'K' 'F' 'q' 'U' 'R' '3' '7' '6' 'z' '-' 'x' 'A' 'j' '4' 'k'
#  'Y' 'D' 'M' 'H' 'O' 'N' 'X' '8' ':' '%' 'Q' '#' '?' '/' '9' 'V' '+' 'ñ'
#  'J' '`' 'W' '@' '&' '(' ')' 'Z' 'ú' '!' '>' 'ó' 'Â' '£' '"' ';' 'à' '®'
#  '¦' '=' 'ä' 'â' '€' '“' 'Ã' '¶' 'Ñ' '_' '📈' 'é' '…' '”' '^' 'á' '«' '|'
#  '[' ']' '~' '{' '}' '¼' '¬' 'í' '<' 'Á' '’']

# %% [markdown]
# # Text Cleaning

# %%
mystopwords =stopwords.words('english')

# %%
def cleanTxt(clean_text):
    # remove numbers and punctuation
    clean_text = re.sub(r'@[A-Za-za-z0-9]+','', clean_text)
    clean_text = re.sub(r'#','', clean_text)
    # remove extra spaces
    clean_text = re.sub(r'RT[\s]+','', clean_text)
    clean_text = re.sub(r'https?:\/\/\S+','', clean_text)
    clean_text ="".join([x for x in clean_text if x not in string.punctuation])
    clean_text = clean_text.lower() # convert to lowercase
    clean_text = re.sub(r'[^a-z0-9\s]', '', clean_text) # remove non-alphanumeric characters
    clean_text = re.sub(' +',' ', clean_text)

    # convert to lowercase
    clean_text = clean_text.lower()
    tokens = clean_text.split(" ")
    tokens =[ token for token in tokens if tokens if token not in mystopwords]
    clean_text=" ".join([ps.stem(token)for token in tokens])
    return clean_text

df['clean_Sentence'] = df['Sentence'].apply(cleanTxt)
df.head()
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence
# 0  geosolut technolog leverag benefon gp solut pr...
# 1                    esi low 150 250 bk real possibl
# 2  last quarter 2010 componenta net sale doubl eu...
# 3  accord finnishrussian chamber commerc major co...
# 4  swedish buyout firm sold remain 224 percent st...

# %%
import neattext.functions as nfx
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'random',
#  're',
#  'read_txt',
#  'remove_accents',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'unicodedata',
#  'word_freq',
#  'word_length_freq']

# %%
df['clean_Sentence']=df['clean_Sentence'].apply(nfx.remove_special_characters)
df['clean_Sentence']=df['clean_Sentence'].apply(nfx.remove_numbers)
df['clean_Sentence']=df['clean_Sentence'].apply(nfx.remove_urls)
df['clean_Sentence']=df['clean_Sentence'].apply(nfx.remove_userhandles)

# %%
unique_chars = pd.Series([char for sentence in df["clean_Sentence"] for char in sentence]).unique()
print("Number of unique chars:",len(unique_chars))
print(unique_chars)
# Out:
# Number of unique chars: 27
# ['g' 'e' 'o' 's' 'l' 'u' 't' ' ' 'c' 'h' 'n' 'v' 'r' 'a' 'b' 'f' 'p' 'i'
#  'd' 'm' 'w' 'k' 'q' 'y' 'z' 'x' 'j']

# %%
import collections

from collections import Counter

# %%
# Stopwords
Stopwords = set(nltk.corpus.stopwords.words("english")) - set(["not"])

def Text_Processing(Text):
    Processed_text = list()
    Lemmatizer = WordNetLemmatizer()

    # Tokens of words
    Token = nltk.word_tokenize(Text)
    for word in Tokens:
        Processed_Text.append(Lemmatizer.lemmatize(word))
    return(" ".join(Processed_Text))

# %%
df.head()
# Out:
#                                             Sentence Sentiment  \
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
#
#                                       clean_Sentence
# 0  geosolut technolog leverag benefon gp solut pr...
# 1                          esi low   bk real possibl
# 2  last quarter  componenta net sale doubl eurm e...
# 3  accord finnishrussian chamber commerc major co...
# 4  swedish buyout firm sold remain  percent stake...

# %%
# Stopwords
Stopwords = set(nltk.corpus.stopwords.words("english")) - set(["not"])

def Text_Processing(Text):
    Processed_text = list()
    Lemmatizer = WordNetLemmatizer()

    # Tokens of words
    Token = nltk.word_tokenize(Text)
    for word in Tokens:
        Processed_Text.append(Lemmatizer.lemmatize(word))
    return(" ".join(Processed_Text))

# %% [markdown]
# # Key Words Extraction

# %%
def extract_keywords(text,num=50):
    tokens = [token for token in text.split()]
    most_comman_tokens= Counter(tokens)
    return dict(most_comman_tokens)

# %%
#define a funtion to plot the Keywords from all the segmenet
def plot_most_comman_words(mydict):
    df_01 = pd.DataFrame(mydict.items(),columns=['tokens','count'])
    plt.figure(figsize=(650,40))
    sns.barplot(x='tokens',y='count',data=df_01)
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Length of the words in the corpus

# %%
# Create a histogram to visualize the length of sentences
sentence_lengths = df['clean_Sentence'].apply(lambda x: len(x))
plt.hist(sentence_lengths, bins=15, color='Purple')
plt.title('Sentence Length Distribution')
plt.xlabel('Sentence Length')
plt.ylabel('Count')
plt.show()

# %%
from wordcloud import WordCloud

# %%
def plot_wordcloud(docx):
    mywordcloud = WordCloud().generate(docx)
    plt.figure(figsize=(20,10))
    plt.imshow(mywordcloud)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Now will Filter out all The Unique Words from all The Sentiments.

# %%
Universal_list = df['clean_Sentence'].values.tolist()
df_U = pd.DataFrame(data =df['clean_Sentence'])
df_U.rename(columns = {'clean_Sentence':'ALL CLEAN SENTENCES'}, inplace = True)
df_U
# Out:
#                                     ALL CLEAN SENTENCES
# 0     geosolut technolog leverag benefon gp solut pr...
# 1                             esi low   bk real possibl
# 2     last quarter  componenta net sale doubl eurm e...
# 3     accord finnishrussian chamber commerc major co...
# 4     swedish buyout firm sold remain  percent stake...
# ...                                                 ...
# 5837  rise cost forc packag produc huhtamaki axe  jo...
# 5838  nordic walk first use summer train method cros...
# 5839  accord ship compani vike line eu decis signifi...
# 5840     build home improv trade sale decreas  eur  mn
# 5841  helsinki afx kci konecran said order four hot ...
#
# [5842 rows x 1 columns]

# %%
most_occuring_wordsU = pd.Series(''.join(df_U['ALL CLEAN SENTENCES']).split()).value_counts()[:100]
Most_occuring_wordsU = pd.DataFrame(data =most_occuring_wordsU)
Most_occuring_wordsU.columns =['Count']
Wordu = Most_occuring_wordsU.index
Most_occuring_wordsU['UWords']=Wordu
Most_occuring_wordsU.reset_index()
# Out:
#       index  Count   UWords
# 0       eur   1626      eur
# 1   compani    890  compani
# 2        mn    815       mn
# 3    profit    594   profit
# 4      oper    591     oper
# ..      ...    ...      ...
# 95  announc     92  announc
# 96     area     92     area
# 97    offer     89    offer
# 98     deal     89     deal
# 99    posit     88    posit
#
# [100 rows x 3 columns]

# %%
plt.figure(figsize=(30,15))
plt.bar(most_occuring_wordsU.index,most_occuring_wordsU.values)
plt.title("Most Occuring words")
plt.xlabel("Words")
plt.ylabel("Frequency of words")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Positive Sentiment Analysis

# %%
positive_list = df[df['Sentiment'] =='positive']['clean_Sentence']
df_6 = pd.DataFrame(data =positive_list)
df_6.rename(columns = {'clean_Sentence':'POSITIVE_SENTENCES'}, inplace = True)
df_6
# Out:
#                                      POSITIVE_SENTENCES
# 0     geosolut technolog leverag benefon gp solut pr...
# 2     last quarter  componenta net sale doubl eurm e...
# 5                   spi wouldnt surpris see green close
# 8     kone net sale rose  yearonyear first nine month
# 10             circul revenu increas  finland  sweden
# ...                                                 ...
# 5819  last month ad gild posit start new one bwld se...
# 5824   newli form compani yit stavo local contact ne...
# 5825  friend life lift profit  hike divi ahead propo...
# 5836  daili mail parent compani talk potenti partner...
# 5841  helsinki afx kci konecran said order four hot ...
#
# [1852 rows x 1 columns]

# %%
from collections import Counter
positive_docx = ''.join(positive_list)
keyword_po = extract_keywords(positive_docx)
Positive_keywords = pd.DataFrame(data =keyword_po ,index=[0])
PosK= set(Positive_keywords)
Positive_keywords.T
# Out:
#                0
# geosolut       1
# technolog     50
# leverag        3
# benefon        5
# gp             3
# ...           ..
# kostiainen     1
# divi           1
# takeovdaili    1
# parent         1
# yhoohelsinki   1
#
# [4473 rows x 1 columns]

# %%
#MOST OCCURING WORDS IN POSITIVE SENTENCES.
most_occuring_wordsP = pd.Series(''.join(df_6['POSITIVE_SENTENCES']).split()).value_counts()[:100]
Most_occuring_wordsPDF = pd.DataFrame(data =most_occuring_wordsP)
Most_occuring_wordsPDF.columns =['Count']
WordP = Most_occuring_wordsPDF.index
Most_occuring_wordsPDF['PWords']=WordP
Most_occuring_wordsPDF.reset_index()
# Out:
#       index  Count   PWords
# 0       eur    581      eur
# 1        mn    257       mn
# 2   compani    223  compani
# 3    profit    222   profit
# 4      sale    217     sale
# ..      ...    ...      ...
# 95     rise     30     rise
# 96       us     30       us
# 97    estim     30    estim
# 98      ceo     30      ceo
# 99    volum     30    volum
#
# [100 rows x 3 columns]

# %%
plot_wordcloud(positive_docx)

# %%
#plot_most_comman_words(keyword_po)

# %% [markdown]
# # Negative Sentences Analysis

# %%
#Negative Sentences
negative_list = df[df['Sentiment'] =='negative']['clean_Sentence']
negative_docx = ''.join(negative_list)
df_7 = pd.DataFrame(data =negative_list)
df_7.rename(columns = {'clean_Sentence':'NEGATIVE_SENTENCES'}, inplace = True)
df_7
# Out:
#                                      NEGATIVE_SENTENCES
# 1                             esi low   bk real possibl
# 6         shell  billion bg deal meet sharehold skeptic
# 7     ssh commun secur corp stock exchang releas oct...
# 11    sap q disappoint softwar licens real problem c...
# 39    aapl afternoon selloff usual brutal get readi ...
# ...                                                 ...
# 5829                       sbux pm db downgrad pt cut
# 5831  finnish develop manufactur mobil phone charger...
# 5832                 oper profit fell eur  mn eur  mn
# 5835       hsbc say unit book  million charg settlement
# 5837  rise cost forc packag produc huhtamaki axe  jo...
#
# [860 rows x 1 columns]

# %%
# Negative KeyWords

keyword_neg = extract_keywords(negative_docx)
Negative_Keywords = pd.DataFrame(data =keyword_neg,index=[0])
NegK= set(Negative_Keywords)
Negative_Keywords.T
# Out:
#                  0
# esi              1
# low             12
# bk               1
# real             4
# possiblshell     1
# ...             ..
# periodsbux       1
# db               1
# salv             1
# settlementrise   1
# hampshir         1
#
# [2457 rows x 1 columns]

# %%
#MOST OCCURING WORDS IN Negative SENTENCES.
most_occuring_wordsN = pd.Series(''.join(df_7['NEGATIVE_SENTENCES']).split()).value_counts()[:100]
Most_occuring_wordsNDF = pd.DataFrame(data =most_occuring_wordsN)
Most_occuring_wordsNDF.columns =['Count']
WordN = Most_occuring_wordsNDF.index
Most_occuring_wordsNDF['NWords']=WordN
Most_occuring_wordsNDF
# Out:
#          Count   NWords
# eur        376      eur
# mn         233       mn
# profit     155   profit
# sale       106     sale
# net         97      net
# ...        ...      ...
# warn        13     warn
# financi     13  financi
# look        13     look
# march       13    march
# post        13     post
#
# [100 rows x 2 columns]

# %%
plot_wordcloud(negative_docx)

# %%
#plot_most_comman_words(keyword_neg)

# %% [markdown]
# # Neutral Sentences Analysis

# %%
#Neutral Sentences
neutral_list = df[df['Sentiment'] =='neutral']['clean_Sentence']
neutral_docx = ''.join(neutral_list)
df_8 = pd.DataFrame(data =neutral_list)
df_8.rename(columns = {'clean_Sentence':'NEUTRAL_SENTENCES'}, inplace = True)
df_8
# Out:
#                                       NEUTRAL_SENTENCES
# 3     accord finnishrussian chamber commerc major co...
# 4     swedish buyout firm sold remain  percent stake...
# 9     stockmann depart store total floor space  squa...
# 13                             vike line cancel servic
# 14    ahlstrom corpor stock exchang announc   total ...
# ...                                                 ...
# 5833   kemira record revenu approxim eur  billion st...
# 5834       invest product develop stood  mln euro  mln
# 5838  nordic walk first use summer train method cros...
# 5839  accord ship compani vike line eu decis signifi...
# 5840     build home improv trade sale decreas  eur  mn
#
# [3130 rows x 1 columns]

# %%
#Neutral KeyWord
keyword_neu = extract_keywords(neutral_docx)
Neutral_Keywords = pd.DataFrame(data =keyword_neu,index=[0])
NeuK= set(Neutral_Keywords)
Neutral_Keywords.T
# Out:
#                  0
# accord          88
# finnishrussian   1
# chamber          2
# commerc          2
# major           33
# ...             ..
# charterrival     1
# bo               1
# endaugust        1
# iii              1
# abbott           1
#
# [5855 rows x 1 columns]

# %%
# Most Occuuring words in Neutral Sentences
most_occuring_words_Neu = pd.Series(''.join(df_8['NEUTRAL_SENTENCES']).split()).value_counts()[:100]
Most_occuring_wordsNEUDF = pd.DataFrame(data =most_occuring_words_Neu)
Most_occuring_wordsNEUDF.columns =['Count']
WordNeu = Most_occuring_wordsNEUDF.index
Most_occuring_wordsNEUDF['NeuWords']=WordNeu
Most_occuring_wordsNEUDF
# Out:
#          Count NeuWords
# eur        668      eur
# compani    594  compani
# share      331    share
# mn         325       mn
# oper       325     oper
# ...        ...      ...
# equip       55    equip
# plc         54      plc
# number      54   number
# inform      54   inform
# offer       54    offer
#
# [100 rows x 2 columns]

# %%
plot_wordcloud(neutral_docx)

# %%
#plot_most_comman_words(keyword_neu)

# %% [markdown]
# # Creating Sets for Set Operations.

# %%
set1 = set(Most_occuring_wordsPDF['PWords'])  # Set of Most Occuring Positive Words
set2 = set(Most_occuring_wordsNDF['NWords'])  #Set of Most Occuring Negative Words 
set3 = set(Most_occuring_wordsNEUDF['NeuWords']) #Set of Most Occuring Neutral Words
setU = set(Most_occuring_wordsU['UWords']) #Set of All The Occuring Words

# %%
result1 = set1.union(set2, set3)
print(result1)
# Out:
# {'equip', 'see', 'compar', 'month', 'third', 'job', 'offic', 'total', 'acquisit', 'gener', 'billion', 'rise', 'manufactur', 'also', 'bank', 'mobil', 'includ', 'hel', 'said', 'agreement', 'due', 'increas', 'day', 'price', 'net', 'plan', 'share', 'euro', 'cut', 'base', 'pretax', 'pct', 'sale', 'fell', 'approxim', 'contract', 'award', 'continu', 'today', 'rose', 'custom', 'long', 'eurm', 'industri', 'stock', 'announc', 'solut', 'line', 'corpor', 'compani', 'grew', 'accord', 'declin', 'issu', 'earn', 'posit', 'start', 'period', 'half', 'result', 'system', 'move', 'manag', 'us', 'year', 'project', 'neg', 'nokia', 'oyj', 'end', 'staff', 'lower', 'use', 'group', 'exclud', 'well', 'loss', 'usd', 'back', 'area', 'close', 'suppli', 'plc', 'busi', 'tsla', 'servic', 'oy', 'would', 'mln', 'finland', 'high', 'expect', 'product', 'second', 'revenu', 'helsinki', 'eur', 'technolog', 'profit', 'march', 'per', 'financi', 'ep', 'correspond', 'decreas', 'network', 'aapl', 'fall', 'valu', 'provid', 'construct', 'hit', 'item', 'design', 'amount', 'drop', 'warn', 'right', 'process', 'model', 'plant', 'order', 'look', 'recal', 'part', 'improv', 'board', 'number', 'volum', 'offer', 'mn', 'first', 'develop', 'weak', 'nonrecur', 'million', 'earlier', 'last', 'cost', 'buy', 'annual', 'invest', 'quarter', 'oper', 'inform', 'growth', 'percent', 'sign', 'media', 'short', 'new', 'strong', 'estim', 'post', 'unit', 'ceo', 'option', 'spi', 'build', 'x', 'higher', 'omx', 'maker', 'capit', 'market', 'deal', 'employe', 'time', 'report', 'sell', 'finnish', 'q', 'good'}

# %%
print(set1)
# Out:
# {'see', 'compar', 'month', 'third', 'total', 'acquisit', 'billion', 'rise', 'manufactur', 'also', 'bank', 'mobil', 'hel', 'said', 'agreement', 'increas', 'price', 'net', 'share', 'euro', 'sale', 'contract', 'award', 'continu', 'today', 'rose', 'custom', 'long', 'eurm', 'industri', 'stock', 'solut', 'line', 'corpor', 'compani', 'grew', 'earn', 'posit', 'period', 'result', 'system', 'manag', 'us', 'year', 'nokia', 'oyj', 'group', 'well', 'loss', 'close', 'suppli', 'plc', 'busi', 'servic', 'mln', 'finland', 'high', 'expect', 'product', 'second', 'revenu', 'eur', 'technolog', 'profit', 'per', 'financi', 'correspond', 'network', 'aapl', 'provid', 'order', 'look', 'improv', 'volum', 'offer', 'mn', 'first', 'develop', 'million', 'earlier', 'last', 'cost', 'buy', 'invest', 'quarter', 'oper', 'growth', 'percent', 'sign', 'new', 'strong', 'estim', 'ceo', 'higher', 'maker', 'market', 'time', 'report', 'finnish', 'good'}

# %%
print(set2)
# Out:
# {'compar', 'third', 'month', 'job', 'total', 'billion', 'manufactur', 'also', 'bank', 'hel', 'said', 'due', 'day', 'price', 'net', 'share', 'euro', 'cut', 'pretax', 'pct', 'sale', 'fell', 'contract', 'continu', 'today', 'eurm', 'stock', 'compani', 'declin', 'issu', 'earn', 'period', 'half', 'result', 'system', 'move', 'us', 'year', 'neg', 'oyj', 'end', 'staff', 'lower', 'group', 'exclud', 'loss', 'usd', 'back', 'close', 'tsla', 'mln', 'finland', 'expect', 'product', 'second', 'helsinki', 'eur', 'profit', 'march', 'per', 'financi', 'ep', 'correspond', 'decreas', 'fall', 'aapl', 'hit', 'item', 'amount', 'drop', 'warn', 'model', 'look', 'recal', 'mn', 'first', 'weak', 'nonrecur', 'million', 'earlier', 'last', 'cost', 'quarter', 'oper', 'percent', 'short', 'new', 'estim', 'post', 'unit', 'spi', 'x', 'omx', 'maker', 'market', 'time', 'report', 'sell', 'finnish', 'q'}

# %%
print(set3)
# Out:
# {'equip', 'compar', 'offic', 'total', 'gener', 'manufactur', 'also', 'bank', 'mobil', 'includ', 'hel', 'said', 'price', 'net', 'plan', 'share', 'euro', 'base', 'pct', 'sale', 'approxim', 'contract', 'today', 'industri', 'custom', 'stock', 'announc', 'solut', 'corpor', 'compani', 'accord', 'issu', 'start', 'period', 'result', 'system', 'manag', 'year', 'project', 'nokia', 'oyj', 'end', 'use', 'group', 'well', 'loss', 'area', 'plc', 'busi', 'oy', 'servic', 'would', 'mln', 'finland', 'expect', 'product', 'helsinki', 'eur', 'technolog', 'profit', 'per', 'financi', 'correspond', 'decreas', 'network', 'valu', 'provid', 'construct', 'design', 'amount', 'right', 'process', 'plant', 'order', 'part', 'board', 'number', 'offer', 'mn', 'first', 'develop', 'million', 'annual', 'invest', 'quarter', 'oper', 'inform', 'percent', 'media', 'new', 'unit', 'option', 'build', 'omx', 'capit', 'market', 'deal', 'employe', 'report', 'finnish'}

# %% [markdown]
# ##  Set A contains Top 100 most comman Positive  words; Set B Contains Top 100 most Negative Words; Set C Contains Top 100 most Comman Neutral Words.
# ##### For Finding Out The Unique Words in Sentneces Having Positive Sentences we have to perfom a  Set Operation of A Intersection complement of B union C.
#
#
#
#
#
#  #### The intersection of A and the complement of B union C can be obtained by finding the elements that are in A and not in B union C.

# %% [markdown]
#  We first find the union of B and C using the union() method, and then find the complement by checking which words from the set of all words are not in the union. The resulting complement is stored in the complement variable. Finally, we find the intersection of A and the complement using the intersection() method and store it in the intersection variable. The resulting intersection is printed out.  we first create a set of all words to use in the complement computation, and then check if each word in this set is not in the union of B and C.

# %%
A = {'and', 'be', 'compared', 'second', 'million', 'solutions', 'm', 'to', 'plc', 'period', 'at', 'eurm', 'per', 'more', 'stks', 'which', 'buy', 'corresponding', 'last', 'earlier', 'quarter', 'contract', 'than', 'loss', 'after', 'i', 'in', 'stock', 'mn', 'earnings', 'higher', 'operating', 'euro', 'finland', 't', 'company', 'oyj', 'we', 'co', 'from', 'signed', 'is', 'agreement', 'now', 'a', 'has', 'long', 'by', 'technology', 'share', 'percent', 'increased', 'also', 'market', 'rose', 'for', 'sales', 'with', 'our', 'first', 'aapl', 'been', 'eur', 'business', 'over', 'mln', 'the', 'profit', 'hel', 'net', 'an', 'increase', 'its', 'order', 'up', 'services', 'on', 'as', 'that', 'operations', 'year', 'same', 's', 'of', 'new', 'growth', 'price', 'this', 'said', 'finnish', 'today', 'are', 'http', 'https', 'will', 'it', 'was', 'group', 'good', 'have'}
B = {'and', 'be', 'compared', 'second', 'million', 'm', 'to', 'before', 'period', 'at', 'per', 'stks', 'which', 'corresponding', 'helsinki', 'earlier', 'pct', 'quarter', 'back', 'than', 'loss', 'january', 'after', 'i', 'not', 'in', 'totaled', 'mn', 'operating', 'spy', 'about', 'euro', 'finland', 't', 'company', 'oyj', 'model', 'co', 'usd', 'from', 'x', 'is', 'fall', 'a', 'has', 'half', 'third', 'by', 'bank', 'shares', 'totalled', 'share', 'percent', 'market', 'for', 'sales', 'with', 'down', 'first', 'off', 'short', 'fell', 'result', 'aapl', 'been', 'eur', 'decreased', 'over', 'mln', 'the', 'profit', 'hel', 'net', 'its', 'up', 'on', 'as', 'that', 'omx', 'year', 'same', 'some', 's', 'of', 'tsla', 'price', 'this', 'said', 'finnish', 'today', 'are', 'http', 'lower', 'items', 'https', 'will', 'it', 'was', 'group', 'have'}            
C = {'and', 'their', 'be', 'building', 'compared', 'million', 'm', 'to', 'period', 'well', 'at', 'per', 'which', 'helsinki', 'oy', 'quarter', 'contract', 'board', 'than', 'companies', 'loss', 'according', 'value', 'january', 'products', 'not', 'in', 'stock', 'mn', 'unit', 'operating', 'about', 'production', 'euro', 'based', 'finland', 'construction', 'company', 'oyj', 'corporation', 'from', 'financial', 'is', 'a', 'has', 'other', 'or', 'capital', 'one', 'by', 'bank', 'shares', 'share', 'nokia', 'also', 'market', 'investment', 'development', 'for', 'sales', 'with', 'down', 'first', 'mobile', 'been', 'eur', 'business', 'part', 'decreased', 'plant', 'mln', 'the', 'profit', 'net', 'an', 'service', 'its', 'up', 'services', 'were', 'on', 'as', 'that', 'operations', 'year', 'total', 'some', 's', 'of', 'new', 'this', 'said', 'finnish', 'today', 'are', 'will', 'it', 'was', 'group', 'have'}

# %%
#Printing All The Positive Unique Words Wich Do not Exist in Both Negative and Neutral Sentences.
complementP = {word for word in A.union(B, C) if word not in B.union(C)}
intersectionP = A.intersection(complementP)

print(intersectionP)
# Out:
# {'more', 'last', 'buy', 'signed', 'now', 'increased', 'earnings', 'our', 'increase', 'growth', 'agreement', 'we', 'higher', 'solutions', 'order', 'technology', 'rose', 'eurm', 'long', 'plc', 'good'}

# %%
#Printing All The Negative Unique Words Wich Do not Exist in Both Positive and Neutral Sentences.
complementN= {word for word in B.union(C ,A)  if word not in C.union(A)}
intersectionN = B.intersection(complementN)

print(intersectionN) #34 words
# Out:
# {'totaled', 'third', 'before', 'totalled', 'spy', 'half', 'short', 'fall', 'result', 'items', 'x', 'omx', 'pct', 'fell', 'lower', 'off', 'model', 'usd', 'back', 'tsla'}

# %%
#Printing All The Neutral Unique Words Wich Do not Exist in Both Negative and Positive Sentences.
complementNeu= {word for word in C.union(A, B) if word not in A.union(B)}
intersectionNeu = C.intersection(complementNeu)

print(intersectionNeu)
# Out:
# {'total', 'production', 'mobile', 'or', 'according', 'investment', 'capital', 'unit', 'based', 'value', 'service', 'one', 'nokia', 'products', 'corporation', 'plant', 'financial', 'building', 'well', 'part', 'board', 'were', 'development', 'their', 'construction', 'other', 'companies', 'oy'}

# %% [markdown]
# result = A - (B.union(C))
# print(result)

# %% [markdown]
# # Finding all the unique Keywords Which Do not Overlap in any other Sentiment

# %%
#ALL Positive Keywordd
Pkresult = PosK - (NegK.union(NeuK)) 
print(Pkresult)
# Out:
# {'pyri', 'ceoaspocomp', 'men', 'noon', 'taylor', 'roughwft', 'guineabas', 'macrumor', 'sabmilmetso', 'providdixon', 'adob', 'kinder', 'flagebit', 'poy', 'dunelm', 'bbbi', 'hillshir', 'soardeal', 'dealrapala', 'advancastrazeneca', 'retrofit', 'xpower', 'sonc', 'doesnt', 'finger', 'improb', 'seppl', 'gonna', 'wealth', 'kci', 'groceri', 'tradenet', 'afford', 'postel', 'affarsvarlden', 'annvik', 'sakari', 'annualis', 'biofuelfir', 'diseas', 'mongolia', 'aldi', 'fintech', 'shorscal', 'commentshare', 'frp', 'spear', 'skogberg', 'basebpi', 'bleach', 'bancostheyr', 'questcor', 'temv', 'uh', 'kyronsalmi', 'revenudispos', 'ymi', 'doer', 'drugnet', 'gleneagl', 'chkp', 'gotherefor', 'satisfi', 'doubledeck', 'todayvxx', 'ih', 'bosniaherzegovina', 'lizard', 'gavrilov', 'semi', 'threeday', 'warastrazeneca', 'boreali', 'electrowattekono', 'ilmntechnic', 'ripe', 'cdti', 'processrel', 'nalmefen', 'kep', 'kndi', 'resistplan', 'reluct', 'rbteliasonera', 'linebullish', 'teamtoday', 'imperi', 'travi', 'vana', 'steadisaid', 'strongest', 'gustav', 'iyt', 'netflix', 'peac', 'spa', 'investorplac', 'bouncrost', 'iaci', 'rdc', 'smallcap', 'bctmp', 'thesecond', 'mww', 'earningsrel', 'bottomlin', 'inlin', 'tomorrownflx', 'fastadjust', 'avgo', 'memberfusioniq', 'bullishcommod', 'kasak', 'boom', 'tremend', 'partihallsfrbindelsen', 'bouncpretax', 'lankapaja', 'hod', 'investorastrazeneca', 'tj', 'knowhow', 'bloombergastrazeneca', 'zurich', 'med', 'tewhitbread', 'breakingview', 'twoyear', 'teflon', 'angola', 'craft', 'mbli', 'cnpclose', 'mainz', 'costastrazeneca', 'brazilpretax', 'weekkalnapiliotauro', 'grill', 'daiichi', 'brake', 'olli', 'collaborlscc', 'companiesfresnillo', 'appetit', 'bx', 'ipokesko', 'cupandhandl', 'rut', 'drugbuy', 'fuell', 'retak', 'gartner', 'eightfold', 'cdli', 'chrm', 'halfahair', 'yearcompani', 'onemain', 'endo', 'ibio', 'boutfinnish', 'disordfinnish', 'sectorlaunch', 'lab', 'tapiola', 'databas', 'strengthcompani', 'downtrend', 'movantik', 'liddel', 'msftsvyturysuteno', 'sentri', 'heland', 'sandwich', 'bioc', 'longestablish', 'alltim', 'honkamaa', 'tkk', 'daybroker', 'exposurtotal', 'geenrat', 'stronger', 'amrn', 'signalaccord', 'fgvoip', 'undervalu', 'ryder', 'bloombergfinnish', 'positloss', 'phonebook', 'breakoutq', 'digitupdat', 'ridefinnish', 'custodi', 'comeprofit', 'det', 'roy', 'briefaviva', 'momentino', 'pulpwood', 'eon', 'uab', 'stz', 'forum', 'bbm', 'mover', 'emir', 'rtg', 'lingubase', 'recap', 'weeksvyturysuteno', 'lemanncombin', 'docomo', 'cien', 'sveikato', 'wwwdailystockplayscomturun', 'elqav', 'ordabasi', 'loco', 'movelsedeutsch', 'tradeidea', 'lehman', 'inkinen', 'efov', 'sourcbarclay', 'brkb', 'shimano', 'at', 'rtch', 'doubledigit', 'directscania', 'billionplu', 'pkcv', 'staycourt', 'ennismor', 'trlpc', 'cmon', 'highoper', 'outperform', 'cachet', 'coz', 'hydrocopp', 'fimentor', 'drugmaklegal', 'sanyo', 'bcd', 'asmobil', 'sdlp', 'bto', 'rost', 'winnerdansk', 'sourcplug', 'fbqualcomm', 'bye', 'bouncmarimekko', 'proper', 'beginteva', 'schmardin', 'reslili', 'vp', 'mobileinspir', 'premarket', 'eidesvik', 'iwc', 'kopijyva', 'vxxpcln', 'rori', 'refileupd', 'watco', 'wareh', 'upward', 'efut', 'rcp', 'tza', 'drugruukki', 'cnbc', 'punish', 'longerterm', 'eod', 'arvo', 'ero', 'bristol', 'popgerman', 'obj', 'jumpanalyst', 'ecosystem', 'barclaygreen', 'femsa', 'adjac', 'automobil', 'onethird', 'avcompar', 'ctx', 'strongcru', 'propuls', 'mineffici', 'tieup', 'lateaccord', 'holcim', 'lung', 'xbox', 'pushnews', 'modeexact', 'zero', 'exploit', 'eurusd', 'yesterdaylook', 'consensu', 'luxembourgregist', 'dubna', 'extenslong', 'dara', 'escap', 'waiv', 'rowan', 'hostil', 'ideal', 'artv', 'sweeper', 'therebi', 'bless', 'grainbas', 'embrac', 'nortel', 'intactevenif', 'argu', 'bright', 'stk', 'groupwhitbread', 'heavyduti', 'kingfishfund', 'streak', 'eklund', 'dietz', 'sihvo', 'ftcommenc', 'gainerbrazilian', 'mso', 'pricefiskar', 'convict', 'oem', 'favour', 'electriccar', 'buse', 'mono', 'lindsey', 'ukbas', 'sponsorship', 'dental', 'ponv', ' ...

# %%
Negresult = NegK - (NeuK.union(PosK)) 
print(Negresult)
# Out:
# {'glaxosmithklinfullyear', 'macquari', 'rebuffearn', 'giraff', 'panicpaper', 'thmehhlf', 'britvic', 'pilebreadth', 'resumstx', 'goeadpnew', 'tecnomenresultcow', 'athn', 'mafinnish', 'vs', 'assetsepar', 'kantarfinnish', 'uso', 'shark', 'wayyy', 'strategiamrn', 'growstandard', 'plcoper', 'jefferi', 'weir', 'sfo', 'poopoo', 'flatiwhitbread', 'underperfnet', 'spreadbuild', 'emc', 'exxon', 'slumpoper', 'premarketacad', 'gatecrash', 'losscocacola', 'dragoper', 'estimlg', 'brexitgroup', 'xma', 'stepfinnish', 'armfinnish', 'asiaoper', 'fastddd', 'xleaccord', 'shortglencor', 'pointresult', 'opposit', 'currencnokia', 'coincid', 'clientshort', 'harrison', 'infring', 'greek', 'pott', 'testjanuarynovemb', 'bricolag', 'worrirb', 'illeg', 'capablhack', 'lv', 'mg', 'wayoper', 'gainfinland', 'billionpound', 'faulti', 'sink', 'troublgld', 'chum', 'cree', 'fallamrn', 'rollfinnair', 'raidboe', 'subdu', 'lsedeutsch', 'gainsadv', 'mcd', 'cvx', 'kfinlandbas', 'vetr', 'didnt', 'swi', 'putrival', 'earngoogl', 'plumbertsla', 'firsthalf', 'mini', 'probablaccord', 'slidestanchart', 'nq', 'skepticssh', 'lousi', 'scandaladdit', 'judgspi', 'tslaaccord', 'bell', 'emptivaisala', 'worripretax', 'compq', 'glutcerberu', 'bearish', 'shipstarbuck', 'afsi', 'dbo', 'planq', 'jnpr', 'reversinglook', 'dx', 'rg', 'jd', 'ugaz', 'academ', 'fastjet', 'ofix', 'attackftse', 'bno', 'mitk', 'tslatullow', 'pare', 'zoneq', 'vixverizon', 'gtat', 'zsl', 'gogo', 'sndk', 'routenergi', 'periomx', 'seatbelt', 'blrx', 'darn', 'gmcr', 'nyseba', 'anyth', 'rivalshell', 'chit', 'homebuild', 'shottalentum', 'wti', 'shellbg', 'falltsla', 'guessoper', 'watchlisttesla', 'comibin', 'setupsteelmak', 'siga', 'transoceanscanfil', 'android', 'esi', 'brick', 'grpn', 'tastlondon', 'kantaroper', 'spillrel', 'fals', 'yndx', 'grocer', 'that', 'rbi', 'profitspi', 'fearsbux', 'movestumbl', 'twtrbobe', 'cat', 'hhhmm', 'bgreduct', 'destroyadp', 'stepmorrison', 'riskglencor', 'cliff', 'candlstandard', 'tslasamsung', 'hdge', 'fragil', 'bailout', 'possiblshell', 'brentupdat', 'heed', 'backadpnew', 'pfinnish', 'pollut', 'followfinnish', 'shortcost', 'growrevenu', 'holi', 'highroyal', 'axethird', 'dji', 'underwhelm', 'policiisolation', 'competithand', 'junip', 'contractu', 'weakest', 'vmarket', 'tue', 'yearberkshir', 'everydaywhich', 'closurtsla', 'dividendpcln', 'halliburton', 'stelio', 'caretesco', 'dropsale', 'closecopper', 'expiri', 'plcaapl', 'imearlier', 'dnf', 'thought', 'dvax', 'pre', 'bitter', 'bowl', 'probebaltic', 'pressurcapac', 'sad', 'nya', 'reed', 'companieskingfish', 'ftcnobodi', 'havent', 'bacdue', 'sheryl', 'lonminmoment', 'abandon', 'asmb', 'wprofit', 'hangin', 'crest', 'sina', 'defect', 'tslahk', 'sherlockeuropean', 'camt', 'breach', 'ani', 'vzsale', 'stockfinnish', 'tellkonecran', 'ba', 'lpg', 'picker', 'touchcompaniestesco', 'mflx', 'dealoper', 'imhoiff', 'dive', 'headgmcr', 'pullbacktim', 'talktalk', 'earlicompar', 'cherri', 'blipoper', 'penaltipetrofac', 'disappointadministr', 'faith', 'mcfarlan', 'foul', 'touchftse', 'areanext', 'bat', 'sbuxaccord', 'nomura', 'backcompar', 'aramco', 'ecbaapl', 'crox', 'probelast', 'clockworkoper', 'evas', 'sidelinsever', 'earnprice', 'untru', 'cutair', 'slapmulti', 'forget', 'horribl', 'lowermorrison', 'spiaxdx', 'xlb', 'tslaq', 'advert', 'su', 'putearn', 'dividendyelp', 'resultresult', 'modelx', 'closehowev', 'slam', 'soda', 'sensex', 'areafinnish', 'sap', 'earnoper', 'moneytsla', 'runup', 'breakdown', 'fmcn', 'bump', 'enoughpoorest', 'cashmcd', 'kaman', 'okay', 'donald', 'super', 'gilead', 'goodtesla', 'hover', 'bpfinnair', 'shortreturn', 'cannot', 'latch', 'shareswil', 'devalu', 'correspondglencor', 'notebuild', 'ddd', 'kill', 'intc', 'untur', 'fadefinnish', 'prompt', 'tollfinnish', 'outflow', 'aberdeen', 'bleed', 'overhead', 'mondayqihu', 'lack', 'pickup', 'tang', 'yeah', 'attackfb', 'crack', 'motiva', 'spihznp', 'costco', 'jeopardichang', 'setback', 'contest', 'acom', 'beaten', 'canceraspocomp', 'cisco', 'lossbwld', 'marketcase', 'unusu', 'disturbb ...

# %%
Neuresult = NeuK - (PosK.union(NegK)) 
print(Neuresult)
# Out:
# {'redeliveri', 'sama', 'telecomm', 'dopplr', 'etth', 'lundberg', 'gunneflo', 'oka', 'appealcost', 'metropolitan', 'soosalu', 'statist', 'ignatiu', 'walden', 'tuoma', 'nordalu', 'kasei', 'bollor', 'maltid', 'sister', 'promo', 'odel', 'skier', 'maarten', 'kgroup', 'plaqu', 'singlechannel', 'freighter', 'count', 'html', 'provision', 'nonrestrict', 'dualfuel', 'knickerbock', 'newlycomplet', 'captur', 'lynn', 'hook', 'rotana', 'kr', 'kangasala', 'lappeenranta', 'dinosaur', 'worldclass', 'marek', 'earlicoke', 'mere', 'kilo', 'draft', 'permiss', 'nda', 'agj', 'frequent', 'pentti', 'dohl', 'pro', 'avista', 'bluebird', 'companiesdiageo', 'thoughtgroup', 'onetim', 'squar', 'clientel', 'nonperform', 'counterpart', 'crecent', 'weblog', 'tuomo', 'multistorey', 'karttakesku', 'pact', 'live', 'modifi', 'thailand', 'downplay', 'ssh', 'musthav', 'oscar', 'cabot', 'modif', 'djsi', 'multichannel', 'absente', 'michelin', 'sentera', 'inventor', 'finan', 'pensioenfond', 'evidentiari', 'noponen', 'thermal', 'sabharw', 'niina', 'receipt', 'congress', 'intrigu', 'basest', 'mezzanin', 'rinkuskiai', 'creditor', 'motorola', 'hypotek', 'ilkkayhtym', 'parvi', 'takanen', 'prohibit', 'asc', 'innofactor', 'dna', 'independ', 'pyszni', 'crude', 'belveder', 'class', 'stylis', 'lieksaar', 'bochum', 'vishakapatnam', 'wintek', 'seng', 'laavainen', 'calif', 'compulsori', 'info', 'filmiteollisuu', 'rake', 'umbrella', 'dart', 'financialwir', 'shanahan', 'weatherdeck', 'seafood', 'tourist', 'storey', 'srl', 'vibrocompactor', 'avi', 'liechtenstein', 'efi', 'remov', 'album', 'machineroomless', 'prolin', 'davi', 'betoni', 'plx', 'saavalainen', 'agricol', 'curb', 'hu', 'tyrvaan', 'nord', 'compressor', 'stateapprov', 'aleksandri', 'duet', 'doctor', 'guinea', 'mold', 'sole', 'hspa', 'saarioinen', 'tomato', 'tameer', 'mantsala', 'airbalt', 'bavaria', 'guatemala', 'januaryaugust', 'kaivooja', 'blog', 'lc', 'skandinaviska', 'mechanizac', 'n', 'separationfiltr', 'frontedg', 'cliffton', 'artist', 'hevea', 'asfaltti', 'club', 'maijaliisa', 'ceoloudey', 'mformat', 'teu', 'sanomawsoy', 'psoriasi', 'commerzbank', 'bonu', 'pharmacodynam', 'tulla', 'newark', 'nmlist', 'ubnt', 'directroshan', 'domino', 'pti', 'lewa', 'igor', 'cater', 'yearlong', 'den', 'towertop', 'lagarder', 'phoenix', 'wifi', 'electrif', 'baba', 'shad', 'speaker', 'inhibitor', 'surfacetreat', 'vista', 'cerberu', 'valuead', 'alfa', 'intens', 'costanza', 'kariniemi', 'schultz', 'utah', 'threeunder', 'cannon', 'yearonyeafortum', 'washout', 'supercalend', 'chaseoper', 'disclaim', 'refut', 'blow', 'spray', 'irrevoc', 'parnu', 'mlnon', 'chicago', 'molten', 'investlesprom', 'eronen', 'coarrang', 'precipit', 'compagni', 'kstore', 'cm', 'kymi', 'gatehous', 'surcharg', 'preempt', 'puljonki', 'es', 'moorestown', 'debentur', 'ilmarinen', 'outlin', 'aso', 'shb', 'appointkarppinen', 'tenth', 'hitura', 'companyeur', 'frolov', 'fork', 'bento', 'northwest', 'suonenjoen', 'preemptiv', 'offenburg', 'galeria', 'invent', 'sarantel', 'dri', 'agent', 'suez', 'pine', 'career', 'kazan', 'rollon', 'morvillar', 'antniemi', 'mcafe', 'scene', 'fray', 'kiikoinen', 'split', 'salvor', 'sauk', 'bakeri', 'pekkarinen', 'cadmodel', 'galeri', 'worldlead', 'embark', 'borrow', 'ivori', 'pb', 'altima', 'ann', 'mantyharju', 'trojan', 'bangkok', 'formadehyd', 'f', 'ylinen', 'greatest', 'palmberg', 'omeo', 'wwwfiskarscom', 'spoke', 'dusseldorf', 'rib', 'fcc', 'stroi', 'simpl', 'reisholz', 'climat', 'overse', 'attend', 'wwwsanomacom', 'rent', 'myspacecom', 'auction', 'campofrio', 'castecka', 'qualifi', 'loudeac', 'newstex', 'skandinavian', 'label', 'creativ', 'written', 'nearshor', 'dave', 'rvr', 'nonvis', 'telco', 'tripolibas', 'consequ', 'enclos', 'novotel', 'lcd', 'cellular', 'northrhin', 'mba', 'underperfoper', 'marko', 'sled', 'stereotyp', 'wwwcernercom', 'karkkila', 'anttila', 'wooden', 'verif', 'vacanc', 'votorantim', 'repoq', 'weekend', 'poznan', 'slit', 'op', 'resign', 'flurri', 'kolorit', 'agrefinnish', 'ecofriendli', 'nst', 'gambl', 'basement', 'foll ...

# %%
# create three lists of words
#Unique_Positive_Words = ['1', 'posit', 'improv', 'award', 'increas', 'grew', 'growth', 'look', 'suppli', 'time', 'plc', 'higher', 'high', 'line', 'good', 'revenu', 'offer', 'long', 'agreement', 'buy', 'strong', 'rose', 'earn', 'sign']
#Unique_Negative_Words = ['item', 'spi', 'day', 'fell', 'lower', 'tsla', 'exclud', 'staff', 'usd', 'short', 'job', 'fall', 'half', 'back', 'estim', 'model', 'declin', 'cut', 'move', 'pretax', '5', 'us', '25', 'weak', 'x', 'due', 'drop', 'hit', '6', 'billion', 'sell', 'recal', '2700', '2']
#Unique_Neutral_Words = ['valu', 'base', 'design', 'process', 'gener', 'announc', 'deal', 'project', 'accord', 'would', 'plan', 'use', 'board', 'approxim', 'start', 'construct', 'includ', 'right', 'financi', 'oy', 'option', 'offic', 'build', 'part', 'plant', 'capit', 'annual', 'area', 'media', 'employe']

# %%
stoplist = stopwords.words('english') + ['though']

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stoplist, ngram_range=(1,1))
# matrix of ngrams
ngrams = c_vec.fit_transform(df['clean_Sentence'])
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
Unigram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'Frequency', 1:'Unigram'})
Unigram.iloc[:100]
# Out:
#     Frequency  Unigram
# 0        1627      eur
# 1         917  compani
# 2         815       mn
# 3         633     oper
# 4         607     sale
# ..        ...      ...
# 95         94  network
# 96         94  announc
# 97         93    would
# 98         91    posit
# 99         91    offer
#
# [100 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stoplist, ngram_range=(2,2))
# matrix of ngrams
ngrams = c_vec.fit_transform(df['clean_Sentence'])
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
Bigram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'bigram'})
Bigram.iloc[:100]
#fig = px.bar(df_ngram.iloc[:100], x="frequency", y="bigram", title='Commmon unigram in Negative Reviews', orientation='h', width=700, height=700,color='bigram')
#fig.show()
# Out:
#     frequency          bigram
# 0         774          eur mn
# 1         276        net sale
# 2         245     eur million
# 3         243     oper profit
# 4         195          mn eur
# ..        ...             ...
# 95         22  baltic countri
# 96         21     xac million
# 97         21    previou year
# 98         21     period year
# 99         21       new share
#
# [100 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stoplist, ngram_range=(3,3))
# matrix of ngrams
ngrams = c_vec.fit_transform(df['clean_Sentence'])
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
Trigram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'Trigram'})
Trigram
# Out:
#        frequency                   Trigram
# 0            193                 mn eur mn
# 1            191                eur mn eur
# 2            126              mln euro mln
# 3            123              total eur mn
# 4             85      mn correspond period
# ...          ...                       ...
# 41841          1        aapl aapl gundlach
# 41842          1           aapl aapl final
# 41843          1  aaltonen finland develop
# 41844          1     aalto univers univers
# 41845          1             aal pm london
#
# [41846 rows x 2 columns]

# %% [markdown]
# ## Text Polarity
# We then can calculate the sentiment through the polarity function. polarity ranges from -1 to 1, with -1 being negative and 1 being positive. The TextBlob can also use the subjectivity function to calculate subjectivity, which ranges from 0 to 1, with 0 being objective and 1 being subjective.

# %%
 from textblob import TextBlob
df['polarity'] = df['clean_Sentence'].apply(lambda x: TextBlob(x).polarity)
df['subjective'] = df['clean_Sentence'].apply(lambda x: TextBlob(x).subjectivity)
df.iloc[:50]
# Out:
#                                              Sentence Sentiment  \
# 0   The GeoSolutions technology will leverage Bene...  positive
# 1   $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2   For the last quarter of 2010 , Componenta 's n...  positive
# 3   According to the Finnish-Russian Chamber of Co...   neutral
# 4   The Swedish buyout firm has sold its remaining...   neutral
# 5     $SPY wouldn't be surprised to see a green close  positive
# 6   Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 7   SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 8   Kone 's net sales rose by some 14 % year-on-ye...  positive
# 9   The Stockmann department store will have a tot...   neutral
# 10  Circulation revenue has increased by 5 % in Fi...  positive
# 11  $SAP Q1 disappoints as #software licenses down...  negative
# 12  The subdivision made sales revenues last year ...  positive
# 13           Viking Line has canceled some services .   neutral
# 14  Ahlstrom Corporation STOCK EXCHANGE ANNOUNCEME...   neutral
# 15                              $FB gone green on day  positive
# 16  $MSFT SQL Server revenue grew double-digit wit...  positive
# 17  According to L+ñnnen Tehtaat 's CEO Matti Karp...   neutral
# 18  The company 's share is quoted on NASDAQ OMX H...   neutral
# 19  Elcoteq SE is listed on the Nasdaq OMX Helsink...   neutral
# 20  Two of these contracts are for turntable anode...   neutral
# 21  Aviva, Friends Life top forecasts ahead of 5.6...  positive
# 22  In stead of being based on a soft drink , as i...   neutral
# 23  The company plans to increase the unit 's spec...   neutral
# 24  The company closed last year with a turnover o...   neutral
# 25  Shire CEO steps up drive to get Baxalta board ...  positive
# 26  Costco: A Premier Retail Dividend Play https:/...  positive
# 27  The five-storey , eco-efficient building will ...   neutral
# 28  The first installment of the Cinema Series con...   neutral
# 29                                  All are welcome .   neutral
# 30  Stockmann and Swedish sector company AB Lindex...  positive
# 31  HUHTAMAKI OYJ STOCK EXCHANGE RELEASE , 16.9.20...   neutral
# 32  `` We are pleased to welcome Tapeks Noma into ...  positive
# 33  - Profit before taxes was EUR 105.9 82.7 milli...   neutral
# 34  Royal Dutch Shell to Buy BG Group for Nearly $...  positive
# 35  FinancialWire tm is not a press release servic...   neutral
# 36  ASSA ABLOY Kaupthing Bank gave a ` neutral ' r...   neutral
# 37  The item included restructuring costs of EUR1 ...  positive
# 38  In 2005 the bank posted a net profit of Lt 8.2...   neutral
# 39  $AAPL afternoon selloff as usual will be bruta...  negative
# 40  $TSLA recalling pretty much every single model...  negative
# 41  Dolce & Gabbana has asked the European Union t...  negative
# 42  InterContinental Hotels first-quarter global r...  negative
# 43  According to Finnish pension insurance company...  positive
# 44  A portion , $ 12.5 million , will be recorded ...  positive
# 45  L&G still paying price for dividend cut during...  negative
# 46  The volume of investments in the two phases of...   neutral
# 47  Russia accounted for 9 % of the Lagardere maga...   neutral
# 48  The company also estimates the already carried...  positive
# 49   Profit of the accounting period was EUR 0.3 mn .   neutral
#
#                                        clean_Sentence  polarity  subjective
# 0   geosolut technolog leverag benefon gp solut pr... -0.331818    0.727273
# 1                           esi low   bk real possibl  0.100000    0.300000
# 2   last quarter  componenta net sale doubl eurm e...  0.000000    0.188889
# 3   accord finnishrussian chamber commerc major co...  0.062500    0.500000
# 4   swedish buyout firm sold remain  percent stake... -0.100000    0.233333
# 5                 spi wouldnt surpris see green close -0.200000    0.300000
# 6       shell  billion bg deal meet sharehold skeptic  0.000000    0.000000
# 7   ssh commun secur corp stock exchang releas oct...  0.350000    0.550000
# 8   kone net sale rose  yearonyear first nine month    0.283333    0.427778
# 9   stockmann depart store total floor space  squa...  0.000000    0.750000
# 10           circul revenu increas  finland  sweden    0.000000    0.000000
# 11  sap q disappoint softwar licens real problem c...  0.200000    0.300000
# 12  subdivis made sale revenu last year eur  milli...  0.000000    0.066667
# 13                           vike line cancel servic   0.000000    0.000000
# 14  ahlstrom corpor stock exchang announc   total ...  0.140693    0.580087
# 15                                  fb gone green day -0.200000    0.300000
# 16  msft sql server revenu grew doubledigit sql se...  0.000000    0.000000
# 17  accord lnnen tehtaat ceo matti karppinen compa...  0.000000    0.450000
# 18  compani share quot nasdaq omx helsinki rautaru...  0.000000    0.000000
# 19           elcoteq se list nasdaq omx helsinki ltd   0.000000    0.000000
# 20  two contract turntabl anod vibrocompactor deli...  0.000000    0.000000
# 21  aviva friend life top forecast ahead  billion ...  0.500000    0.500000
# 22  stead base soft drink usual teho energi drink ... -0.162500    0.525000
# 23  compani plan increas unit specialist staff sev...  0.000000    0.000000
# 24  compani close last year turnov four million euro   0.000000    0.066667
# 25        shire ceo step drive get baxalta board talk  0.000000    0.000000
# 26           costco premier retail dividend play cost  0.000000    0.000000
# 27  fivestorey ecoeffici build gross floor area  s...  0.000000    0.000000
# 28  first instal cinema seri conclud profil finnis...  0.250000    0.333333
# 29                                            welcom   0.000000    0.000000
# 30  stockmann swedish sector compani ab lindex ent...  0.000000    0.066667
# 31  huhtamaki oyj stock exchang releas   huhtamaki...  0.000000    0.000000
# 32               pleas welcom tapek noma cramo group   0.000000    0.000000
# 33                          profit tax eur   million   0.000000    0.000000
# 34     royal dutch shell buy bg group nearli  billion  0.000000    0.000000
# 35  financialwir tm press releas servic receiv com...  0.000000    0.000000
# 36  assa abloy kaupth bank gave neutral recommend ...  0.000000    0.000000
# 37  item includ restructur cost eur  year earlier ...  0.000000    0.500000
# 38                       bank post net profit lt  mn   0.000000    0.000000
# 39  aapl afternoon selloff usual brutal get readi ... -0.562500    0.625000
# 40  tsla recal pretti much everi singl model x got...  0.100000    0.250000
# 41  dolc gabbana ask european union declar marimek...  0.000000    0.000000
# 42  intercontinent hotel firstquart global room re...  0.000000    0.000000
# 43  accord finnish pension insur compani varma var...  0.000000    0.000000
# 44  portion  million record part win prior patent ...  0.400000    0.200000
# 45    lg still pay price dividend cut crisi chief say  0.000000    0.000000
# 46  volum invest two phase project estim usd mn eu...  0.000000    0.000000
# 47  russia account  lagarder magazin divis revenu ...  0.000000    0.000000
# 48  compani also estim alreadi carri invest lead i...  0.000000    0.000000
# 49                     profit account period eur  mn   0.000000    0.000000

# %%
common_unibigrams = pd.merge(Unigram, Bigram, left_on='Unigram', right_on='bigram', how='inner')

# %%
common_unibitrigrams = pd.merge(common_unibigrams, Trigram, left_on='Unigram', right_on='Trigram', how='inner')

# %%
unique_unigrams = set(Unigram['Unigram']) - set(common_unibitrigrams['Unigram'])

# %%
unique_bigrams = set(Bigram['bigram']) - set(common_unibitrigrams['bigram'])
unique_trigrams = set(Trigram['Trigram']) - set(common_unibitrigrams['Trigram'])

# %%
print(unique_bigrams)
# Out:
# {'poll analyst', 'wwwseahawkdrillingcom investor', 'ship like', 'interest compani', 'ownerengin wastewat', 'lehdentekijat unit', 'servic custom', 'name new', 'group insur', 'one attract', 'expans breakout', 'solteq expand', 'fluid bed', 'ep continu', 'new kveyt', 'promo video', 'meat process', 'tax expens', 'result sale', 'gener capac', 'aim expand', 'biohit alreadi', 'profit forecast', 'boat net', 'bank group', 'ratasmaki busi', 'deliveri enabl', 'group life', 'financi coven', 'tesco criticis', 'sport oyj', 'lead content', 'result third', 'million loss', 'firm smith', 'major owner', 'lahtinen project', 'mln ton', 'bag anoth', 'optimist amzn', 'frame facad', 'loss busi', 'quarter tikkurila', 'metso suppli', 'extract circuit', 'googl buy', 'paper chemic', 'previous said', 'subsidiari kolkata', 'sale come', 'monday expect', 'intern financi', 'harbour servic', 'occur march', 'gener annual', 'significantli increas', 'concentr sale', 'rout stockholm', 'charg court', 'posit financ', 'suppli autom', 'vantaa plant', 'week howev', 'estim hotel', 'share sale', 'post earn', 'respect compar', 'start local', 'track still', 'music platinum', 'im still', 'aim increas', 'brian burton', 'technolog group', 'still exist', 'bit higher', 'grew juli', 'hotel restaur', 'chanc mayb', 'sinter lump', 'heart drug', 'land secur', 'post strong', 'unnam russian', 'former aspocomp', 'alway lead', 'glaston also', 'eightfold tb', 'profit program', 'turnov whole', 'near term', 'player stavebni', 'five differ', 'updat outlin', 'jeder betatest', 'year ict', 'finnish busi', 'locat worldwid', 'activ advertis', 'video project', 'tax amount', 'hold ameripric', 'keep bank', 'finnish meat', 'finland profit', 'brand tectia', 'warn cisco', 'capac mw', 'advantag voic', 'tsla avail', 'year experi', 'hkscan finland', 'ilim bratsk', 'factor percentag', 'yhoo crazi', 'million cash', 'still happi', 'bank downgrad', 'wish increas', 'point spread', 'romosozumab men', 'compani net', 'unit smithfield', 'dress style', 'eur util', 'evli properti', 'invent relat', 'shape minut', 'gartner specialist', 'custom increas', 'work carri', 'hold januari', 'flow gener', 'ftse gainer', 'unibrew rais', 'juli jan', 'system intermitt', 'yhoo fishi', 'finnish share', 'facil made', 'control posit', 'lt said', 'despit sale', 'system implement', 'face sfo', 'requir result', 'dog owner', 'children teenag', 'rove employ', 'emc sndk', 'underground park', 'nv tekla', 'compani award', 'trailer unit', 'bull hat', 'ppl love', 'higher clubcard', 'part plan', 'previou project', 'data servic', 'design homewar', 'sausag offer', 'ago sept', 'per share', 'quick higher', 'screen system', 'trade love', 'caus talentum', 'bay work', 'profession servic', 'demand finland', 'today onlin', 'nextgener smartphon', 'buy integr', 'brista combin', 'current drought', 'kesko group', 'crash accord', 'persist without', 'ag konecran', 'alfa megafon', 'conduct taloustutkimu', 'fed day', 'hel poh', 'product util', 'fall print', 'dpz broke', 'immedi vicin', 'said nokia', 'district court', 'ceo vodafon', 'grocer face', 'delhi feb', 'breez mix', 'industri wast', 'extens experi', 'team ugglarp', 'lithuanian breweri', 'forc end', 'week waterqueen', 'secur digit', 'document function', 'giant shad', 'iprint oy', 'elektrobit oyj', 'hike threat', 'insur compani', 'lousi spread', 'toppi imho', 'second reader', 'proha plc', 'particip big', 'voic data', 'rule nasdaq', 'taken consider', 'compani gama', 'pirkka tomato', 'clarifi group', 'airlin order', 'center offic', 'slaughterhous team', 'ahead ab', 'vnet biv', 'inci outperform', 'across samsung', 'sharehold approv', 'parser buy', 'book discuss', 'includ figur', 'citi mainor', 'sbux pm', 'total componenta', 'offer strengthen', 'twitter twtr', 'demograph inform', 'finnish petrol', 'beij shanghai', 'alpina ski', 'electron pipett', 'hkscan corpor', 'llc sna', 'year year', 'abl avoid', 'gasolin deliveri', 'heindlmey said', 'bid said', 'type properti', 'km south', 'comptel said', 'nokia oyj', 'volu ...

# %%
print(unique_trigrams)
# Out:
# {'yearonyear eur august', 'machineri work taken', 'begin year wartsila', 'final make gain', 'arrang custom respons', 'continu earlier collabor', 'partner sawmil oper', 'ecuador commiss poyri', 'arto ryymin born', 'locat nokia telecom', 'magazin teacher choic', 'accord suomen projektivuokrau', 'howev shortterm rental', 'overshadow larg number', 'share shall acquir', 'sale decreas pct', 'low voltag drive', 'plant group trim', 'contract manufactur employe', 'iwm buy program', 'standard life announc', 'decis commerci plant', 'boy geniu report', 'licens agreement sunnuntai', 'million goodwil compani', 'qpr repres saudi', 'finnish bank card', 'pct lower point', 'sign exclus fiveyear', 'board pcb nokia', 'around mln unit', 'smaller ship compani', 'kraftheinz merger came', 'alberta well certifi', 'rapid expans market', 'steel maker said', 'industri chang busi', 'compar friday high', 'malaysia studi trip', 'innov award nexbtl', 'vessel lower present', 'period million euro', 'two fierc storm', 'compani golden state', 'kong hang seng', 'fennia kesko group', 'tanzania award poyri', 'usual euro million', 'fesco finnish logist', 'tallinnhelisnki link claim', 'six geograph area', 'eur may finnish', 'ssh commun secur', 'bank group lay', 'cover equip depot', 'veil variou type', 'commerc latter compani', 'million usd given', 'distribut fund start', 'improv eur eur', 'counter offer blackston', 'heindlmey said beyond', 'isrg trade alltim', 'dilut ep came', 'capman four invest', 'year contract suppli', 'share price ralli', 'member dafcu merg', 'newli creat posit', 'board advanc maximum', 'advantag voic direct', 'innovest global list', 'follow onlin via', 'raisio food divis', 'aapl goldman sach', 'suspect take high', 'partner oy develop', 'due prolong project', 'train paintshop owner', 'diverg place launch', 'mean come kid', 'decemb outotec establish', 'oper profit declin', 'number concept store', 'stay close matter', 'field combin power', 'tectia corpor hel', 'trend line buy', 'forest industri group', 'maximum grade veneer', 'establish global sale', 'noora niiininoski explain', 'elect vice chairman', 'follow snapback vix', 'implement new inform', 'steel iron ore', 'turnov eur vaahto', 'height mr metso', 'fell previou account', 'product suppli enexi', 'fiveyear servic contract', 'continu area resist', 'srv success compet', 'support hs setup', 'hold via option', 'rule base manag', 'expect deliv annual', 'consolid move higher', 'share becom subject', 'stock option total', 'bahia state brazil', 'metallurg plant relat', 'plan spend proce', 'america africa asia', 'filledlookin short opt', 'fair valu share', 'tieto offer aktia', 'sole respons content', 'phone includ ngb', 'educ scienc organ', 'measur includ increas', 'cu welcom damemb', 'handl system provid', 'finnish lnnen tehtaat', 'dish cocktail glass', 'grapevin carri lot', 'finland export line', 'corp rose thursday', 'capman plc invest', 'warren buffett defend', 'leap uk biggest', 'heat form hot', 'dilut control system', 'adac judgement latest', 'swing loss drop', 'green bottl new', 'media net sale', 'bodi open procedur', 'curl latest bestsel', 'protalix biotherapeut inc', 'tonn per day', 'product finnish kemijrvi', 'expect show slight', 'week near lose', 'finnish crosscountri skier', 'commerci deploy master', 'dpz loco insid', 'acerta secur next', 'centr turku school', 'nasdaq omx helsinki', 'energi process industri', 'servic card retail', 'postpaid bill charg', 'oper grew eur', 'olkiluoto plant gener', 'steel manufactur plan', 'integr support wonderwar', 'agre import estonian', 'tsla recal big', 'thermal spray coat', 'done solut corpor', 'area govern manufactur', 'paid resid privaci', 'sabharw ashutosh aazhang', 'brother year select', 'wide rang mobil', 'share carri may', 'oyj omx vacv', 'employe vari one', 'govern financi market', 'ftse ralli threemonth', 'plc aso plc', 'eye ra takeov', 'preempt consum want', 'year largest facil', 'america green experi', 'ratio staff total', 'cf pti ltd', 'vicepr ...

# %%
common_bigrams = set(Bigram['bigram']).intersection(set(common_unibitrigrams['bigram']))
common_trigrams = set(Trigram['Trigram']).intersection(set(common_unibitrigrams['Trigram']))

# %% [markdown]
#  you can use the intersection operation to find the words that are present in both sets of bigrams/trigrams.
#
#
# This will give you sets of bigrams and trigrams that are present in both the original set and the common set. You can use these common bigrams/trigrams in to capture important patterns and relationships in the text data.

# %%
features = list(common_unibitrigrams['Unigram']) + list(common_bigrams) + list(common_trigrams) + list(unique_bigrams) + list(unique_trigrams)
df_features= pd.DataFrame({'Features': features})
df_features
# Out:
#                              Features
# 0                        poll analyst
# 1      wwwseahawkdrillingcom investor
# 2                           ship like
# 3                    interest compani
# 4                 ownerengin wastewat
# ...                               ...
# 80173                    ad data show
# 80174  strengthen partnership telemig
# 80175        orhangazi foundri modern
# 80176              tvo said shortlist
# 80177              oper coscom execut
#
# [80178 rows x 1 columns]

# %%
# Define a function to calculate sentiment and subjectivity of a sentence
def get_sentiment_subjectivity(sentence):
    blob = TextBlob(sentence)
    sentiment = blob.sentiment.polarity
    
    if sentiment > 0:
        return "positive", sentiment
    elif sentiment < 0:
        return "negative", sentiment
    else:
        return "neutral", sentiment

# Apply the function to the 'clean_Sentence' column of your DataFrame and store the results in new columns
df['sentiment'], df['polarity'] = zip(*df['clean_Sentence'].apply(get_sentiment_subjectivity))

# %% [markdown]
# This will create three new columns named sentiment, polarity, and subjectivity in your DataFrame, which contain the sentiment, polarity, and subjectivity scores of each sentence, respectively.

# %%
df
# Out:
#                                                Sentence Sentiment  \
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
#                                          clean_Sentence  polarity  subjective  \
# 0     geosolut technolog leverag benefon gp solut pr... -0.331818    0.727273
# 1                             esi low   bk real possibl  0.100000    0.300000
# 2     last quarter  componenta net sale doubl eurm e...  0.000000    0.188889
# 3     accord finnishrussian chamber commerc major co...  0.062500    0.500000
# 4     swedish buyout firm sold remain  percent stake... -0.100000    0.233333
# ...                                                 ...       ...         ...
# 5837  rise cost forc packag produc huhtamaki axe  jo...  0.000000    0.000000
# 5838  nordic walk first use summer train method cros...  0.250000    0.333333
# 5839  accord ship compani vike line eu decis signifi...  0.000000    0.000000
# 5840     build home improv trade sale decreas  eur  mn   0.000000    0.000000
# 5841  helsinki afx kci konecran said order four hot ...  0.250000    0.850000
#
#      sentiment
# 0     negative
# 1     positive
# 2      neutral
# 3     positive
# 4     negative
# ...        ...
# 5837   neutral
# 5838  positive
# 5839   neutral
# 5840   neutral
# 5841  positive
#
# [5842 rows x 6 columns]

# %%
df.drop(['Sentence', 'Sentiment'], axis='columns', inplace=True)

# %%
X= df['clean_Sentence']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit(X)
X = vectorizer.transform(X)

# %%
from sklearn.preprocessing import  LabelEncoder

# %%
le = LabelEncoder()
df["sentiment"] = le.fit_transform(df["sentiment"])

# %%
df["sentiment"].value_counts()
# Out:
# 1    3915
# 2    1361
# 0     566
# Name: sentiment, dtype: int64

# %%
#Neutral -3915 ->1
#positive - 1316  ->2
#Negative - 860  ->0

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (2, 2))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape
# Out:
# (5842, 5000)

# %%
# Declaring our target variable
y = df["sentiment"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_absolute_percentage_error, mean_squared_error, roc_auc_score, auc, log_loss, precision_recall_fscore_support, mean_absolute_error
from sklearn.metrics import roc_curve

# %% [markdown]
# # Model1 : Naive Bayes

# %% [markdown]
# # Bigram

# %%
# Train a Naive Bayes classifier on the vectorized data
clf = MultinomialNB()
clf.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test set and evaluate the model
y_pred_train_NB = clf.predict(X_train)
y_pred_test_nb = clf.predict(X_test)
acc_train_1 = accuracy_score(y_train, y_pred_train_NB)
acc_test_1 = accuracy_score(y_test, y_pred_test_nb)
cm = confusion_matrix(y_test, y_pred_test_nb)

# %%
print("Classification report : \n",classification_report(y_test,y_pred_test_nb))
print("Training Accuracy Score",acc_train_1)
print("Testing Accuracy Score",acc_test_1)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.78      0.05      0.09       151
#            1       0.71      0.99      0.83       964
#            2       0.80      0.27      0.41       346
#
#     accuracy                           0.72      1461
#    macro avg       0.76      0.44      0.44      1461
# weighted avg       0.74      0.72      0.65      1461
#
# Training Accuracy Score 0.795023967130792
# Testing Accuracy Score 0.7200547570157426

# %%
cm = confusion_matrix(y_test,y_pred_test_nb)
class_label = ["Positive", "Negative","Neutral"]
df_cm = pd.DataFrame(cm, index = class_label, columns = class_label)
sns.heatmap(df_cm, annot = True, fmt = "d", cmap='YlGnBu')
plt.title('Confusion matrix for Naive Bayes', fontsize = 20);
plt.title("confusion matrix", y=1.1)
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
plt.show()

# %% [markdown]
# # Trigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (3, 3))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
# Train a Naive Bayes classifier on the vectorized data
clf = MultinomialNB()
clf.fit(X_train,y_train)
y_pred_test_nb = clf.predict(X_test)
acc_test_1 = accuracy_score(y_test, y_pred_test_nb)
# Print classification report
print(classification_report(y_test, y_pred_test_nb))
print("Testing Accuracy Score",acc_test_1)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.06      0.11       151
#            1       0.70      0.99      0.82       964
#            2       0.76      0.20      0.32       346
#
#     accuracy                           0.70      1461
#    macro avg       0.82      0.42      0.42      1461
# weighted avg       0.74      0.70      0.63      1461
#
# Testing Accuracy Score 0.7049965776865161

# %% [markdown]
# # Unigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (1, 1))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
# Train a Naive Bayes classifier on the vectorized data
clf = MultinomialNB()
clf.fit(X_train,y_train)
y_pred_test_nb = clf.predict(X_test)
acc_test_1 = accuracy_score(y_test, y_pred_test_nb)
# Print classification report
print(classification_report(y_test, y_pred_test_nb))
print("Testing Accuracy Score",acc_test_1)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.05       151
#            1       0.70      0.99      0.82       964
#            2       0.76      0.21      0.33       346
#
#     accuracy                           0.71      1461
#    macro avg       0.82      0.41      0.40      1461
# weighted avg       0.75      0.71      0.63      1461
#
# Testing Accuracy Score 0.7070499657768652

# %% [markdown]
# # Model2 : Support vector machine

# %% [markdown]
# # Unigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (1, 1))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
y_pred_test_svm = clf.predict(X_test)
acc_test_2 = accuracy_score(y_test, y_pred_test_svm)
# Print classification report
print(classification_report(y_test, y_pred_test_svm))
print("Testing Accuracy Score",acc_test_2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.34      0.51       151
#            1       0.80      1.00      0.89       964
#            2       0.97      0.58      0.73       346
#
#     accuracy                           0.83      1461
#    macro avg       0.91      0.64      0.71      1461
# weighted avg       0.86      0.83      0.81      1461
#
# Testing Accuracy Score 0.8336755646817249

# %% [markdown]
# # Trigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (3, 3))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
y_pred_test_svm = clf.predict(X_test)
acc_test_2 = accuracy_score(y_test, y_pred_test_svm)
# Print classification report
print(classification_report(y_test, y_pred_test_svm))
print("Testing Accuracy Score",acc_test_2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.17      0.28       151
#            1       0.70      0.98      0.82       964
#            2       0.79      0.17      0.28       346
#
#     accuracy                           0.71      1461
#    macro avg       0.79      0.44      0.46      1461
# weighted avg       0.74      0.71      0.63      1461
#
# Testing Accuracy Score 0.7063655030800822

# %% [markdown]
# # Bigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (2, 2))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])
X1 =df["clean_Sentence"]
# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
# Train a Support Vector Machine classifier on the vectorized data
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Make predictions on the test set and evaluate the model
y_pred_train_SVM = clf.predict(X_train)
y_pred_test_svm = clf.predict(X_test)
acc_train_2 = accuracy_score(y_train, y_pred_train_SVM)
acc_test_2 = accuracy_score(y_test, y_pred_test_svm)
cm = confusion_matrix(y_test, y_pred_test_svm)

# %%
print("Classification report : \n",classification_report(y_test,y_pred_test_svm))
print("Training Accuracy Score",acc_train_2)
print("Testing Accuracy Score",acc_test_2)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.19      0.30       151
#            1       0.72      0.99      0.84       964
#            2       0.90      0.28      0.43       346
#
#     accuracy                           0.74      1461
#    macro avg       0.82      0.49      0.52      1461
# weighted avg       0.78      0.74      0.68      1461
#
# Training Accuracy Score 0.8913490070760101
# Testing Accuracy Score 0.7392197125256673

# %%
cm = confusion_matrix(y_test,y_pred_test_svm)
class_label = ["Positive", "Negative","Neutral"]
df_cm = pd.DataFrame(cm, index = class_label, columns = class_label)
sns.heatmap(df_cm, annot = True, fmt = "d", cmap='YlGnBu')
plt.title('Confusion matrix for Naive Bayes', fontsize = 20);
plt.title("confusion matrix", y=1.1)
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
plt.show()

# %% [markdown]
# # Model3 : Random Forest

# %% [markdown]
# # Unigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (1, 1))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred_train_RF = clf.predict(X_train)
y_pred_test_rf = clf.predict(X_test)
acc_train_3 = accuracy_score(y_train, y_pred_train_RF)
acc_test_3 = accuracy_score(y_test, y_pred_test_rf)
# Print classification report
print("Classification Report For training data Set")
print(classification_report(y_train,  y_pred_train_RF))
print("Classification Report For testing data Set")
print(classification_report(y_test, y_pred_test_rf))
print("Training Accuracy Score",acc_train_3)
print("Testing Accuracy Score",acc_test_3)
f1_score_train =f1_score(y_train,clf.predict(X_train),average="weighted")
f1_score_test =f1_score(y_test,clf.predict(X_test),average="weighted")
print("F1 Score training dateset for RandomForest Classifier: %s" % f1_score_train)
print("F1 Score training dateset for RandomForest Classifier: %s" % f1_score_test)
# Out:
# Classification Report For training data Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       415
#            1       1.00      1.00      1.00      2951
#            2       1.00      1.00      1.00      1015
#
#     accuracy                           1.00      4381
#    macro avg       1.00      1.00      1.00      4381
# weighted avg       1.00      1.00      1.00      4381
#
# Classification Report For testing data Set
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.86       151
#            1       0.95      1.00      0.98       964
#            2       0.97      0.92      0.94       346
#
#     accuracy                           0.96      1461
#    macro avg       0.96      0.90      0.92      1461
# weighted avg       0.96      0.96      0.96      1461
#
# Training Accuracy Score 1.0
# Testing Accuracy Score 0.9568788501026694
# F1 Score training dateset for RandomForest Classifier: 1.0
# F1 Score training dateset for RandomForest Classifier: 0.9556085014296805

# %%
pipe_lr = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 1))),
    ('clf', RandomForestClassifier())
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size = 0.25, random_state = 42)

# %%
pipe_lr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', RandomForestClassifier())])

# %%
pipe_lr.score(X_test,y_test)
# Out:
# 0.9507186858316222

# %%
ex1 = "The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model ."

# %%
pipe_lr.predict([ex1])
# Out:
# array([2])

# %%
ex2 = "Shell's $70 Billion BG Deal Meets Shareholder Skepticism"

# %%
pipe_lr.predict([ex2])
# Out:
# array([1])

# %%
ex3 = "The Swedish buyout firm has sold its remaining 22.4 percent stake , almost eighteen months after taking the company public in Finland ."

# %%
pipe_lr.predict([ex3])
# Out:
# array([0])

# %%
pipe_lr.predict_proba([ex2])
# Out:
# array([[0.01, 0.99, 0.  ]])

# %%
import joblib
pipeline_file = open("finall.pkl","wb")
joblib.dump(pipe_lr,pipeline_file)
pipeline_file.close()

# %% [markdown]
# # Bigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (2, 2))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)

y_pred_test_rf = clf.predict(X_test)
acc_test_3 = accuracy_score(y_test, y_pred_test_rf)
# Print classification report
print(classification_report(y_test, y_pred_test_rf))
print("Testing Accuracy Score",acc_test_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.28      0.41       151
#            1       0.76      0.96      0.85       964
#            2       0.79      0.40      0.53       346
#
#     accuracy                           0.76      1461
#    macro avg       0.75      0.55      0.60      1461
# weighted avg       0.76      0.76      0.73      1461
#
# Testing Accuracy Score 0.759069130732375

# %% [markdown]
# # Trigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (3, 3))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
# Train a random forest classifier on the vectorized data
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Make predictions on the test set and evaluate the model
y_pred_train_RF = clf.predict(X_train)
y_pred_test_rf = clf.predict(X_test)
acc_train_3 = accuracy_score(y_train, y_pred_train_RF)
acc_test_3 = accuracy_score(y_test, y_pred_test_rf)
cm = confusion_matrix(y_test, y_pred_test_rf)

# %%
print("Classification report : \n",classification_report(y_test,y_pred_test_rf))
print("Training Accuracy Score",acc_train_3)
print("Testing Accuracy Score",acc_test_3)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.73      0.18      0.29       151
#            1       0.72      0.97      0.82       964
#            2       0.78      0.27      0.40       346
#
#     accuracy                           0.72      1461
#    macro avg       0.74      0.47      0.50      1461
# weighted avg       0.73      0.72      0.67      1461
#
# Training Accuracy Score 0.8057521113900936
# Testing Accuracy Score 0.7214236824093087

# %%
cm = confusion_matrix(y_test,y_pred_test_rf)
class_label = ["Positive", "Negative","Neutral"]
df_cm = pd.DataFrame(cm, index = class_label, columns = class_label)
sns.heatmap(df_cm, annot = True, fmt = "d", cmap='YlGnBu')
plt.title('Confusion matrix for Random forest ', fontsize = 20);
plt.title("confusion matrix", y=1.1)
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
plt.show()

# %% [markdown]
# # Model4 : Dicision Tree

# %% [markdown]
# # Unigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (1, 1))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier =DecisionTreeClassifier(criterion='entropy')
classifier.fit(X_train, y_train)
y_pred_train_dt = classifier.predict(X_train)
y_pred_test_dt = classifier.predict(X_test)
acc_train_dt = accuracy_score(y_train, y_pred_train_dt)
acc_test_dt = accuracy_score(y_test, y_pred_test_dt)
# Print classification report
print("Classification Report For training data Set")
print(classification_report(y_train,  y_pred_train_dt))
print("Classification Report For testing data Set")
print(classification_report(y_test, y_pred_test_dt))
print("Testing Accuracy Score",acc_train_dt)
print("Testing Accuracy Score",acc_test_dt)
f1_score_train =f1_score(y_train,classifier.predict(X_train),average="weighted")
f1_score_test =f1_score(y_test,classifier.predict(X_test),average="weighted")
print("F1 Score training dateset for RandomForest Classifier: %s" % f1_score_train)
print("F1 Score training dateset for RandomForest Classifier: %s" % f1_score_test)
# Out:
# Classification Report For training data Set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       415
#            1       1.00      1.00      1.00      2951
#            2       1.00      1.00      1.00      1015
#
#     accuracy                           1.00      4381
#    macro avg       1.00      1.00      1.00      4381
# weighted avg       1.00      1.00      1.00      4381
#
# Classification Report For testing data Set
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       151
#            1       0.98      0.99      0.98       964
#            2       0.94      0.95      0.94       346
#
#     accuracy                           0.96      1461
#    macro avg       0.95      0.92      0.93      1461
# weighted avg       0.96      0.96      0.96      1461
#
# Testing Accuracy Score 1.0
# Testing Accuracy Score 0.9630390143737166
# F1 Score training dateset for RandomForest Classifier: 1.0
# F1 Score training dateset for RandomForest Classifier: 0.9625025617928348

# %% [markdown]
# # Trigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (3, 3))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier =DecisionTreeClassifier(criterion='entropy')
classifier.fit(X_train, y_train)
y_pred_test_dt = classifier.predict(X_test)
acc_test_4 = accuracy_score(y_test, y_pred_test_dt)
# Print classification report
print(classification_report(y_test, y_pred_test_dt))

print("Testing Accuracy Score",acc_test_4)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.18      0.28       151
#            1       0.71      0.96      0.82       964
#            2       0.75      0.26      0.39       346
#
#     accuracy                           0.71      1461
#    macro avg       0.69      0.47      0.49      1461
# weighted avg       0.71      0.71      0.66      1461
#
# Testing Accuracy Score 0.7132101300479123

# %% [markdown]
# # Bigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (2, 2))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier =DecisionTreeClassifier(criterion='entropy')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# Make predictions on the test set and evaluate the model
y_pred_train_DT = classifier.predict(X_train)
y_pred_test_dt = classifier.predict(X_test)
acc_train_4 = accuracy_score(y_train, y_pred_train_DT)
acc_test_4 = accuracy_score(y_test, y_pred_test_dt)
cm = confusion_matrix(y_test, y_pred_test_dt)

# %%
acc4 = accuracy_score(y_test,y_pred_test_dt)
print("Classification report : \n",classification_report(y_test,y_pred_test_dt))
print("Training Accuracy Score",acc_train_4)
print("Testing Accuracy Score",acc_test_4)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.59      0.31      0.41       151
#            1       0.76      0.93      0.83       964
#            2       0.70      0.41      0.51       346
#
#     accuracy                           0.74      1461
#    macro avg       0.68      0.55      0.58      1461
# weighted avg       0.73      0.74      0.71      1461
#
# Training Accuracy Score 0.9169139465875371
# Testing Accuracy Score 0.7392197125256673

# %%
cm = confusion_matrix(y_test,y_pred_test_dt)
class_label = ["Positive", "Negative","Neutral"]
df_cm = pd.DataFrame(cm, index = class_label, columns = class_label)
sns.heatmap(df_cm, annot = True, fmt = "d", cmap='YlGnBu')
plt.title('Confusion matrix for Decision Tree ', fontsize = 20);
plt.title("confusion matrix", y=1.1)
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
plt.show()

# %% [markdown]
# # Model5 : K-Nearest Neighbors

# %% [markdown]
# # Unigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (1, 1))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN =KNeighborsClassifier(n_neighbors=10,p=2)
KNN.fit(X_train, y_train)
y_pred_train_KNN = KNN.predict(X_train)
y_pred_test_knn = KNN.predict(X_test)
acc_train_5 = accuracy_score(y_train, y_pred_train_KNN)
acc_test_5 = accuracy_score(y_test, y_pred_test_knn)

# %%
print("Classification report : \n",classification_report(y_test,y_pred_test_knn))
print("Training Accuracy Score",acc_train_5)
print("Testing Accuracy Score",acc_test_5)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.15      0.25       151
#            1       0.71      0.99      0.83       964
#            2       0.81      0.23      0.36       346
#
#     accuracy                           0.72      1461
#    macro avg       0.78      0.45      0.48      1461
# weighted avg       0.74      0.72      0.66      1461
#
# Training Accuracy Score 0.7589591417484592
# Testing Accuracy Score 0.7200547570157426

# %% [markdown]
# # Bigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (2, 2))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN =KNeighborsClassifier(n_neighbors=10,p=2)
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred_train_KNN = KNN.predict(X_train)
y_pred_test_knn = KNN.predict(X_test)
acc_train_5 = accuracy_score(y_train, y_pred_train_KNN)
acc_test_5 = accuracy_score(y_test, y_pred_test_knn)

cm = confusion_matrix(y_test, y_pred_test_knn)

# %%
acc5 = accuracy_score(y_test,y_pred_test_knn)
print("Classification report : \n",classification_report(y_test,y_pred_test_knn))
print("Training Accuracy Score",acc_train_5)
print("Testing Accuracy Score",acc_test_5)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.67      0.01      0.03       151
#            1       0.67      1.00      0.80       964
#            2       0.87      0.06      0.11       346
#
#     accuracy                           0.67      1461
#    macro avg       0.74      0.36      0.31      1461
# weighted avg       0.72      0.67      0.56      1461
#
# Training Accuracy Score 0.6984706687970783
# Testing Accuracy Score 0.6728268309377139

# %%
cm = confusion_matrix(y_test,y_pred_test_knn)
class_label = ["Positive", "Negative","Neutral"]
df_cm = pd.DataFrame(cm, index = class_label, columns = class_label)
sns.heatmap(df_cm, annot = True, fmt = "d", cmap='YlGnBu')
plt.title('Confusion matrix for Decision Tree ', fontsize = 20);
plt.title("confusion matrix", y=1.1)
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
plt.show()

# %% [markdown]
# # Trigram

# %%
# Defining our vectorizer with total words of 5000 and with bigram model
TF_IDF = TfidfVectorizer(max_features = 5000, ngram_range = (3, 3))

# Fitting and transforming our reviews into a matrix of weighed words
# This will be our independent features
X = TF_IDF.fit_transform(df["clean_Sentence"])

# Check our matrix shape
X.shape

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN =KNeighborsClassifier(n_neighbors=10,p=2)
KNN.fit(X_train, y_train)
y_pred_train_KNN = KNN.predict(X_train)
y_pred_test_knn = KNN.predict(X_test)
acc_train_5 = accuracy_score(y_train, y_pred_train_KNN)
acc_test_5 = accuracy_score(y_test, y_pred_test_knn)

# %%
print("Classification report : \n",classification_report(y_test,y_pred_test_knn))
print("Training Accuracy Score",acc_train_5)
print("Testing Accuracy Score",acc_test_5)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       151
#            1       0.66      1.00      0.80       964
#            2       1.00      0.03      0.05       346
#
#     accuracy                           0.67      1461
#    macro avg       0.55      0.34      0.28      1461
# weighted avg       0.67      0.67      0.54      1461
#
# Training Accuracy Score 0.6868294909837936
# Testing Accuracy Score 0.6659822039698836

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import pandas as pd

# %%
X= df['clean_Sentence'].values
y = df["sentiment"].values

# %%
# Create unigram, bigram, and trigram models

vectorizer1 = CountVectorizer(ngram_range=(1,1))
vectorizer2 = CountVectorizer(ngram_range=(2,2))
vectorizer3 = CountVectorizer(ngram_range=(3,3))

# %%
X1 = vectorizer1.fit_transform(X)
X2 = vectorizer2.fit_transform(X)
X3 = vectorizer3.fit_transform(X)

# %%
# Train models and get accuracy scores

models = [
    MultinomialNB(),
    SVC(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    KNeighborsClassifier()
]

# %%
model_names = [
    "Naive Bayes",
    "Support Vector",
    "Random Forest",
    "Decision Tree",
    "K Nearest"
]

# %%
import pandas as pd

# create dictionary of model results
results = {
    'Model': ['Naive Bayes', 'Support Vector', 'Random Forest', 'Decision Tree', 'K Nearest'],
    'Unigram Accu': [0.8161576513288841, 0.8507361550169769, 0.9609706123404754, 0.9738086875073175, 0.711398255473598],
    'Bigram Accu': [0.5313224446786091, 0.7292032548881864, 0.7706258049408734, 0.7814087928813956, 0.6745978222690552],
    'Trigram Accu': [0.45378351481091206, 0.7155087226320103, 0.7449502400187331, 0.7434094368340943, 0.6359027046013347],
    'Combined Accu': [0.600421203606135, 0.7651493775123912, 0.8255155524333606, 0.8328756390742692, 0.6739662607813294]
}

# create DataFrame and transpose
df = pd.DataFrame.from_dict(results)
df = df.set_index('Model')

# display DataFrame
print(df)
# Out:
#                 Unigram Accu  Bigram Accu  Trigram Accu  Combined Accu
# Model
# Naive Bayes         0.816158     0.531322      0.453784       0.600421
# Support Vector      0.850736     0.729203      0.715509       0.765149
# Random Forest       0.960971     0.770626      0.744950       0.825516
# Decision Tree       0.973809     0.781409      0.743409       0.832876
# K Nearest           0.711398     0.674598      0.635903       0.673966

# %%
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split


# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
    
# vectorize data into unigrams, bigrams, and trigrams
cv1 = CountVectorizer(ngram_range=(1,1))
cv2 = CountVectorizer(ngram_range=(2,2))
cv3 = CountVectorizer(ngram_range=(3,3))

X_train_ug = cv1.fit_transform(X_train)
X_train_bg = cv2.fit_transform(X_train)
X_train_tg = cv3.fit_transform(X_train)

X_test_ug = cv1.transform(X_test)
X_test_bg = cv2.transform(X_test)
X_test_tg = cv3.transform(X_test)

# create models
nb_ug = MultinomialNB()
nb_bg = MultinomialNB()
nb_tg = MultinomialNB()

svm_ug = SVC(kernel='linear')
svm_bg = SVC(kernel='linear')
svm_tg = SVC(kernel='linear')

rf_ug = RandomForestClassifier()
rf_bg = RandomForestClassifier()
rf_tg = RandomForestClassifier()

dt_ug = DecisionTreeClassifier()
dt_bg = DecisionTreeClassifier()
dt_tg = DecisionTreeClassifier()

knn_ug = KNeighborsClassifier()
knn_bg = KNeighborsClassifier()
knn_tg = KNeighborsClassifier()

# train models
nb_ug.fit(X_train_ug, y_train)
nb_bg.fit(X_train_bg, y_train)
nb_tg.fit(X_train_tg, y_train)

svm_ug.fit(X_train_ug, y_train)
svm_bg.fit(X_train_bg, y_train)
svm_tg.fit(X_train_tg, y_train)

rf_ug.fit(X_train_ug, y_train)
rf_bg.fit(X_train_bg, y_train)
rf_tg.fit(X_train_tg, y_train)

dt_ug.fit(X_train_ug, y_train)
dt_bg.fit(X_train_bg, y_train)
dt_tg.fit(X_train_tg, y_train)

knn_ug.fit(X_train_ug, y_train)
knn_bg.fit(X_train_bg, y_train)
knn_tg.fit(X_train_tg, y_train)

# predict on test set
nb_ug_pred = nb_ug.predict(X_test_ug)
nb_bg_pred = nb_bg.predict(X_test_bg)
nb_tg_pred = nb_tg.predict(X_test_tg)

svm_ug_pred = svm_ug.predict(X_test_ug)
svm_bg_pred = svm_bg.predict(X_test_bg)
svm_tg_pred = svm_tg.predict(X_test_tg)

rf_ug_pred = rf_ug.predict(X_test_ug)
rf_bg_pred = rf_bg.predict(X_test_bg)
rf_tg_pred = rf_tg.predict(X_test_tg)

dt_ug_pred = dt_ug.predict(X_test_ug)
dt_bg_pred = dt_bg.predict(X_test_bg)
dt_tg_pred = dt_tg.predict(X_test_tg)

knn_ug_pred = knn_ug.predict(X_test_ug)
knn_bg_pred = knn_bg.predict(X_test_bg)
knn_tg_pred = knn_tg.predict(X_test_tg)

# %%
# print classification report and accuracy for each model
print("Multinomial Naive Bayes with Unigram features:\n", classification_report(y_test, nb_ug_pred))
print("Accuracy:", accuracy_score(y_test, nb_ug_pred))
print("\nMultinomial Naive Bayes with Bigram features:\n", classification_report(y_test, nb_bg_pred))
print("Accuracy:", accuracy_score(y_test, nb_bg_pred))
print("\nMultinomial Naive Bayes with Trigram features:\n", classification_report(y_test, nb_tg_pred))
print("Accuracy:", accuracy_score(y_test, nb_tg_pred))
# Out:
# Multinomial Naive Bayes with Unigram features:
#                precision    recall  f1-score   support
#
#            0       0.66      0.36      0.47       151
#            1       0.87      0.92      0.89       964
#            2       0.73      0.76      0.74       346
#
#     accuracy                           0.82      1461
#    macro avg       0.75      0.68      0.70      1461
# weighted avg       0.81      0.82      0.81      1461
#
# Accuracy: 0.8220396988364134
#
# Multinomial Naive Bayes with Bigram features:
#                precision    recall  f1-score   support
#
#            0       0.82      0.18      0.29       151
#            1       0.75      0.96      0.84       964
#            2       0.75      0.43      0.55       346
#
#     accuracy                           0.75      1461
#    macro avg       0.77      0.52      0.56      1461
# weighted avg       0.76      0.75      0.72      1461
#
# Accuracy: 0.7549623545516769
#
# Multinomial Naive Bayes with Trigram features:
#                precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29       151
#            1       0.72      0.98      0.83       964
#            2       0.77      0.25      0.38       346
#
#     accuracy                           0.72      1461
#    macro avg       0.83      0.47      0.50      1461
# weighted avg       0.76      0.72      0.67      1461
#
# Accuracy: 0.7248459958932238

# %%
print("\nSVM with Unigram features:\n", classification_report(y_test, svm_ug_pred))
print("Accuracy:", accuracy_score(y_test, svm_ug_pred))
print("\nSVM with Bigram features:\n", classification_report(y_test, svm_bg_pred))
print("Accuracy:", accuracy_score(y_test, svm_bg_pred))
print("\nSVM with Trigram features:\n", classification_report(y_test, svm_tg_pred))
print("Accuracy:", accuracy_score(y_test, svm_tg_pred))
# Out:
# SVM with Unigram features:
#                precision    recall  f1-score   support
#
#            0       0.91      0.77      0.84       151
#            1       0.95      0.99      0.97       964
#            2       0.95      0.88      0.92       346
#
#     accuracy                           0.95      1461
#    macro avg       0.94      0.88      0.91      1461
# weighted avg       0.95      0.95      0.94      1461
#
# Accuracy: 0.945927446954141
#
# SVM with Bigram features:
#                precision    recall  f1-score   support
#
#            0       0.97      0.23      0.37       151
#            1       0.73      1.00      0.84       964
#            2       0.92      0.31      0.46       346
#
#     accuracy                           0.75      1461
#    macro avg       0.88      0.51      0.56      1461
# weighted avg       0.80      0.75      0.70      1461
#
# Accuracy: 0.7529089664613279
#
# SVM with Trigram features:
#                precision    recall  f1-score   support
#
#            0       0.96      0.17      0.28       151
#            1       0.71      1.00      0.83       964
#            2       0.96      0.22      0.36       346
#
#     accuracy                           0.73      1461
#    macro avg       0.88      0.46      0.49      1461
# weighted avg       0.80      0.73      0.66      1461
#
# Accuracy: 0.7282683093771389

# %%
print("\nRandom Forest with Unigram features:\n", classification_report(y_test, rf_ug_pred))
print("Accuracy:", accuracy_score(y_test, rf_ug_pred))
print("\nRandom Forest with Bigram features:\n", classification_report(y_test, rf_bg_pred))
print("Accuracy:", accuracy_score(y_test, rf_bg_pred))
print("\nRandom Forest with Trigram features:\n", classification_report(y_test, rf_tg_pred))
print("Accuracy:", accuracy_score(y_test, rf_tg_pred))
# Out:
# Random Forest with Unigram features:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87       151
#            1       0.96      1.00      0.98       964
#            2       0.97      0.92      0.95       346
#
#     accuracy                           0.96      1461
#    macro avg       0.96      0.91      0.93      1461
# weighted avg       0.96      0.96      0.96      1461
#
# Accuracy: 0.9603011635865846
#
# Random Forest with Bigram features:
#                precision    recall  f1-score   support
#
#            0       0.95      0.23      0.37       151
#            1       0.74      1.00      0.85       964
#            2       0.97      0.33      0.49       346
#
#     accuracy                           0.76      1461
#    macro avg       0.89      0.52      0.57      1461
# weighted avg       0.81      0.76      0.71      1461
#
# Accuracy: 0.7611225188227242
#
# Random Forest with Trigram features:
#                precision    recall  f1-score   support
#
#            0       1.00      0.17      0.28       151
#            1       0.71      1.00      0.83       964
#            2       0.96      0.22      0.36       346
#
#     accuracy                           0.73      1461
#    macro avg       0.89      0.46      0.49      1461
# weighted avg       0.80      0.73      0.66      1461
#
# Accuracy: 0.7282683093771389

# %%
print("\nDecision Tree with Unigram features:\n", classification_report(y_test, dt_ug_pred))
print("Accuracy:", accuracy_score(y_test, dt_ug_pred))
print("\nDecision Tree with Bigram features:\n", classification_report(y_test, dt_bg_pred))
print("Accuracy:", accuracy_score(y_test, dt_bg_pred))
print("\nDecision Tree with Trigram features:\n", classification_report(y_test, dt_tg_pred))
print("Accuracy:", accuracy_score(y_test, dt_tg_pred))
# Out:
# Decision Tree with Unigram features:
#                precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89       151
#            1       0.98      1.00      0.99       964
#            2       0.96      0.96      0.96       346
#
#     accuracy                           0.97      1461
#    macro avg       0.96      0.93      0.94      1461
# weighted avg       0.97      0.97      0.97      1461
#
# Accuracy: 0.971252566735113
#
# Decision Tree with Bigram features:
#                precision    recall  f1-score   support
#
#            0       0.83      0.28      0.42       151
#            1       0.76      0.97      0.85       964
#            2       0.81      0.42      0.55       346
#
#     accuracy                           0.77      1461
#    macro avg       0.80      0.56      0.61      1461
# weighted avg       0.78      0.77      0.74      1461
#
# Accuracy: 0.7679671457905544
#
# Decision Tree with Trigram features:
#                precision    recall  f1-score   support
#
#            0       0.89      0.16      0.27       151
#            1       0.71      0.99      0.83       964
#            2       0.89      0.24      0.38       346
#
#     accuracy                           0.73      1461
#    macro avg       0.83      0.46      0.49      1461
# weighted avg       0.77      0.73      0.67      1461
#
# Accuracy: 0.7282683093771389

# %%
print("\nK-Nearest Neighbors with Unigram features:\n", classification_report(y_test, knn_ug_pred))
print("Accuracy:", accuracy_score(y_test, knn_ug_pred))
print("\nK-Nearest Neighbors with Bigram features:\n", classification_report(y_test, knn_bg_pred))
print("Accuracy:", accuracy_score(y_test, knn_bg_pred))
print("\nK-Nearest Neighbors with trigram features:\n", classification_report(y_test, knn_tg_pred))
print("Accuracy:", accuracy_score(y_test, knn_tg_pred))
# Out:
# K-Nearest Neighbors with Unigram features:
#                precision    recall  f1-score   support
#
#            0       0.65      0.22      0.33       151
#            1       0.70      0.99      0.82       964
#            2       0.91      0.12      0.21       346
#
#     accuracy                           0.70      1461
#    macro avg       0.75      0.44      0.45      1461
# weighted avg       0.74      0.70      0.62      1461
#
# Accuracy: 0.702258726899384
#
# K-Nearest Neighbors with Bigram features:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       151
#            1       0.67      1.00      0.80       964
#            2       1.00      0.06      0.12       346
#
#     accuracy                           0.67      1461
#    macro avg       0.56      0.35      0.31      1461
# weighted avg       0.68      0.67      0.56      1461
#
# Accuracy: 0.6748802190280629
#
# K-Nearest Neighbors with trigram features:
#                precision    recall  f1-score   support
#
#            0       0.16      0.08      0.11       151
#            1       0.67      0.95      0.79       964
#            2       1.00      0.05      0.09       346
#
#     accuracy                           0.65      1461
#    macro avg       0.61      0.36      0.33      1461
# weighted avg       0.70      0.65      0.55      1461
#
# Accuracy: 0.6468172484599589

# %%
accuracies = [accuracy_score(y_test, nb_ug_pred), accuracy_score(y_test, nb_bg_pred), accuracy_score(y_test, nb_tg_pred),              accuracy_score(y_test, svm_ug_pred), accuracy_score(y_test, svm_bg_pred), accuracy_score(y_test, svm_tg_pred),              accuracy_score(y_test, rf_ug_pred), accuracy_score(y_test, rf_bg_pred), accuracy_score(y_test, rf_tg_pred),              accuracy_score(y_test, dt_ug_pred), accuracy_score(y_test, dt_bg_pred), accuracy_score(y_test, dt_tg_pred),              accuracy_score(y_test, knn_ug_pred), accuracy_score(y_test, knn_bg_pred), accuracy_score(y_test, knn_tg_pred)]

average_accuracy = sum(accuracies) / len(accuracies)
print("Average accuracy:", average_accuracy)
# Out:
# Average accuracy: 0.7780059320100388
